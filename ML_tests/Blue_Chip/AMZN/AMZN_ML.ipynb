# %% [markdown]
# ### First some pip installs you may need to run code

# %%
pip install -u pandas-datareader

# %%
pip install statsmodels

# %%
pip install pmdarima

# %%
# import librarys
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import os
import time
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse
plt.style.use('seaborn')

# %% [markdown]
# ## Getting Data from Yahoo Finance

# %%
#get Microsoft stock price
msftdf = web.DataReader('msft', data_source='yahoo', start='2019-01-01', end='2021-05-01')

msftdf
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-01-02  101.750000   98.940002   99.550003  101.120003  35329300.0
# 2019-01-03  100.190002   97.199997  100.099998   97.400002  42579100.0
# 2019-01-04  102.510002   98.930000   99.720001  101.930000  44060600.0
# 2019-01-07  103.269997  100.980003  101.639999  102.059998  35656100.0
# 2019-01-08  103.970001  101.709999  103.040001  102.800003  31514400.0
# ...                ...         ...         ...         ...         ...
# 2021-04-26  262.440002  260.170013  261.660004  261.549988  19763300.0
# 2021-04-27  263.190002  260.119995  261.579987  261.970001  31014200.0
# 2021-04-28  256.540009  252.949997  256.079987  254.559998  46903100.0
# 2021-04-29  256.100006  249.000000  255.460007  252.509995  40589000.0
# 2021-04-30  253.080002  249.600006  249.740005  252.179993  30929200.0
#
#              Adj Close
# Date
# 2019-01-02   98.375481
# 2019-01-03   94.756454
# 2019-01-04   99.163513
# 2019-01-07   99.289970
# 2019-01-08  100.009888
# ...                ...
# 2021-04-26  261.549988
# 2021-04-27  261.970001
# 2021-04-28  254.559998
# 2021-04-29  252.509995
# 2021-04-30  252.179993
#
# [587 rows x 6 columns]

# %%
#get Facebook stock price
fbdf = web.DataReader('FB', data_source='yahoo', start='2019-01-01', end='2021-05-01')

fbdf
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-01-02  137.509995  128.559998  128.990005  135.679993  28146200
# 2019-01-03  137.169998  131.119995  134.690002  131.740005  22717900
# 2019-01-04  138.000000  133.750000  134.009995  137.949997  29002100
# 2019-01-07  138.869995  135.910004  137.559998  138.050003  20089300
# 2019-01-08  143.139999  139.539993  139.889999  142.529999  26263800
# ...                ...         ...         ...         ...       ...
# 2021-04-26  305.799988  301.559998  303.339996  303.040009  16172600
# 2021-04-27  305.339996  301.109985  304.279999  303.570007  15309300
# 2021-04-28  310.920013  305.369995  307.359985  307.100006  33907200
# 2021-04-29  331.809998  321.609985  330.119995  329.510010  56526800
# 2021-04-30  329.820007  324.500000  326.140015  325.079987  26322000
#
#              Adj Close
# Date
# 2019-01-02  135.679993
# 2019-01-03  131.740005
# 2019-01-04  137.949997
# 2019-01-07  138.050003
# 2019-01-08  142.529999
# ...                ...
# 2021-04-26  303.040009
# 2021-04-27  303.570007
# 2021-04-28  307.100006
# 2021-04-29  329.510010
# 2021-04-30  325.079987
#
# [587 rows x 6 columns]

# %%
#get Apple stock price
aapldf = web.DataReader('AAPL', data_source='yahoo', start='2019-01-01', end='2021-05-01')

aapldf
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-01-02   39.712502   38.557499   38.722500   39.480000  148158800.0
# 2019-01-03   36.430000   35.500000   35.994999   35.547501  365248800.0
# 2019-01-04   37.137501   35.950001   36.132500   37.064999  234428400.0
# 2019-01-07   37.207500   36.474998   37.174999   36.982498  219111200.0
# 2019-01-08   37.955002   37.130001   37.389999   37.687500  164101200.0
# ...                ...         ...         ...         ...          ...
# 2021-04-26  135.059998  133.559998  134.830002  134.720001   66905100.0
# 2021-04-27  135.410004  134.110001  135.009995  134.389999   66015800.0
# 2021-04-28  135.020004  133.080002  134.309998  133.580002  107760100.0
# 2021-04-29  137.070007  132.449997  136.470001  133.479996  151101000.0
# 2021-04-30  133.559998  131.070007  131.779999  131.460007  109713200.0
#
#              Adj Close
# Date
# 2019-01-02   38.439735
# 2019-01-03   34.610851
# 2019-01-04   36.088364
# 2019-01-07   36.008041
# 2019-01-08   36.694466
# ...                ...
# 2021-04-26  134.491562
# 2021-04-27  134.162109
# 2021-04-28  133.353485
# 2021-04-29  133.253662
# 2021-04-30  131.237091
#
# [587 rows x 6 columns]

# %%
#get Google stock price
googdf = web.DataReader('GOOGL', data_source='yahoo', start='2019-01-01', end='2021-05-01')

googdf
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-01-02  1060.790039  1025.280029  1027.199951  1054.680054  1593400
# 2019-01-03  1066.260010  1022.369995  1050.670044  1025.469971  2098000
# 2019-01-04  1080.000000  1036.859985  1042.560059  1078.069946  2301100
# 2019-01-07  1082.699951  1062.640015  1080.969971  1075.920044  2372300
# 2019-01-08  1093.349976  1068.349976  1086.000000  1085.369995  1770700
# ...                 ...          ...          ...          ...      ...
# 2021-04-26  2324.530029  2297.320068  2304.520020  2309.929932  1601900
# 2021-04-27  2318.449951  2286.159912  2317.629883  2290.979980  2219300
# 2021-04-28  2431.379883  2353.219971  2392.500000  2359.040039  4055300
# 2021-04-29  2404.159912  2373.850098  2389.229980  2392.760010  2061700
# 2021-04-30  2381.850098  2346.560059  2368.020020  2353.500000  2242000
#
#               Adj Close
# Date
# 2019-01-02  1054.680054
# 2019-01-03  1025.469971
# 2019-01-04  1078.069946
# 2019-01-07  1075.920044
# 2019-01-08  1085.369995
# ...                 ...
# 2021-04-26  2309.929932
# 2021-04-27  2290.979980
# 2021-04-28  2359.040039
# 2021-04-29  2392.760010
# 2021-04-30  2353.500000
#
# [587 rows x 6 columns]

# %%
#get Amazon stock price
amzndf = web.DataReader('AMZN', data_source='yahoo', start='2019-01-01', end='2021-05-01')

amzndf
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-01-02  1553.359985  1460.930054  1465.199951  1539.130005  7983100
# 2019-01-03  1538.000000  1497.109985  1520.010010  1500.280029  6975600
# 2019-01-04  1594.000000  1518.310059  1530.000000  1575.390015  9182600
# 2019-01-07  1634.560059  1589.189941  1602.310059  1629.510010  7993200
# 2019-01-08  1676.609985  1616.609985  1664.689941  1656.579956  8881400
# ...                 ...          ...          ...          ...      ...
# 2021-04-26  3428.449951  3330.939941  3348.000000  3409.000000  4880700
# 2021-04-27  3460.000000  3398.010010  3443.469971  3417.429932  3827100
# 2021-04-28  3489.879883  3425.000000  3434.800049  3458.500000  4631900
# 2021-04-29  3514.449951  3435.000000  3505.100098  3471.310059  7682400
# 2021-04-30  3554.000000  3462.500000  3525.120117  3467.419922  7001800
#
#               Adj Close
# Date
# 2019-01-02  1539.130005
# 2019-01-03  1500.280029
# 2019-01-04  1575.390015
# 2019-01-07  1629.510010
# 2019-01-08  1656.579956
# ...                 ...
# 2021-04-26  3409.000000
# 2021-04-27  3417.429932
# 2021-04-28  3458.500000
# 2021-04-29  3471.310059
# 2021-04-30  3467.419922
#
# [587 rows x 6 columns]

# %% [markdown]
# ## Visualizing the Data

# %%
#plot close prices
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(msftdf['Close'], label='MSFT')
plt.plot(fbdf['Close'], label='FB')
plt.plot(aapldf['Close'], label='AAPL')
plt.plot(googdf['Close'], label='GOOGL')
plt.plot(amzndf['Close'], label='AMZN')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.title('Volume History')
plt.plot(msftdf['Volume'], label='MSFT')
plt.plot(fbdf['Volume'], label='FB')
plt.plot(aapldf['Volume'], label='AAPL')
plt.plot(googdf['Volume'], label='GOOGL')
plt.plot(amzndf['Volume'], label='AMZN')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.legend()

# %%
#creating new column = 'Total Traded' which is close price * volume

# %%
msftdf['Total Traded'] = msftdf['Close']*msftdf['Volume']
fbdf['Total Traded'] = fbdf['Close']*fbdf['Volume']
aapldf['Total Traded'] = aapldf['Close']*aapldf['Volume']
amzndf['Total Traded'] = amzndf['Close']*amzndf['Volume']
googdf['Total Traded'] = googdf['Close']*googdf['Volume']

# %%
plt.figure(figsize=(16,8))
plt.title('Total Traded History')
plt.plot(msftdf['Total Traded'], label='MSFT')
plt.plot(fbdf['Total Traded'], label='FB')
plt.plot(aapldf['Total Traded'], label='AAPL')
plt.plot(googdf['Total Traded'], label='GOOGL')
plt.plot(amzndf['Total Traded'], label='AMZN')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.legend()

# %% [markdown]
# ##### Before we look at 1 stock change 'ticker'df name to be df so code is reusable with minimal changes

# %%
# INPUT TICKER DF TO BE CHANGED TO 'df' for future code!
df = amzndf

# %%
df
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-01-02  1553.359985  1460.930054  1465.199951  1539.130005  7983100
# 2019-01-03  1538.000000  1497.109985  1520.010010  1500.280029  6975600
# 2019-01-04  1594.000000  1518.310059  1530.000000  1575.390015  9182600
# 2019-01-07  1634.560059  1589.189941  1602.310059  1629.510010  7993200
# 2019-01-08  1676.609985  1616.609985  1664.689941  1656.579956  8881400
# ...                 ...          ...          ...          ...      ...
# 2021-04-26  3428.449951  3330.939941  3348.000000  3409.000000  4880700
# 2021-04-27  3460.000000  3398.010010  3443.469971  3417.429932  3827100
# 2021-04-28  3489.879883  3425.000000  3434.800049  3458.500000  4631900
# 2021-04-29  3514.449951  3435.000000  3505.100098  3471.310059  7682400
# 2021-04-30  3554.000000  3462.500000  3525.120117  3467.419922  7001800
#
#               Adj Close  Total Traded
# Date
# 2019-01-02  1539.130005  1.228703e+10
# 2019-01-03  1500.280029  1.046535e+10
# 2019-01-04  1575.390015  1.446618e+10
# 2019-01-07  1629.510010  1.302500e+10
# 2019-01-08  1656.579956  1.471275e+10
# ...                 ...           ...
# 2021-04-26  3409.000000  1.663831e+10
# 2021-04-27  3417.429932  1.307885e+10
# 2021-04-28  3458.500000  1.601943e+10
# 2021-04-29  3471.310059  2.666799e+10
# 2021-04-30  3467.419922  2.427818e+10
#
# [587 rows x 7 columns]

# %% [markdown]
# ## Take a look at the Data!

# %%
from statsmodels.tsa.stattools import adfuller
#ADF test will tell us if model is stationary. If p-value is greater than .05 we can conclude it is not stationary

result = adfuller(df.Close.dropna())
print(f"ADF Statistic: {result[0]}")
print(f"p-value: {result[1]}")
# Out:
# ADF Statistic: -0.2769416486478157
# p-value: 0.9287071910461647

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,4))

ax1.plot(df.Close)
ax1.set_title('Original')
plot_acf(df.Close, ax=ax2);

# %%
# check if we difference once

diff = df.Close.diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,4))

ax1.plot(diff)
ax1.set_title("Difference once")
plot_acf(diff, ax=ax2);

# %% [markdown]
# ##### We can conclude the data how many times the data should be differenced by the longest line in the auto correlation

# %%
from pmdarima.arima.utils import ndiffs

# %%
#another function to double check # of difference
ndiffs(df.Close, test='adf')
# Out:
# 1

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
diff = df.Close.diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,4))

ax1.plot(diff)
ax1.set_title("Difference once")
ax2.set_ylim(0, 1)
plot_pacf(diff, ax=ax2);

#we see 1 and 9 can be used as p terms

# %%
#Finding q. q is order of the moving average. The # of lagged forecast errors that should go into ARIMA model

# %%
diff = df.Close.diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,4))

ax1.plot(diff)
ax1.set_title("Difference once")
ax2.set_ylim(0,1)
plot_acf(diff, ax=ax2);

#we can see our q term could be 1, 9

# %% [markdown]
# ## Getting started with ARIMA

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA

# %%
#get close data alone

df = df[['Close']].copy()
df.info
# Out:
# <bound method DataFrame.info of                   Close
# Date
# 2019-01-02  1539.130005
# 2019-01-03  1500.280029
# 2019-01-04  1575.390015
# 2019-01-07  1629.510010
# 2019-01-08  1656.579956
# ...                 ...
# 2021-04-26  3409.000000
# 2021-04-27  3417.429932
# 2021-04-28  3458.500000
# 2021-04-29  3471.310059
# 2021-04-30  3467.419922
#
# [587 rows x 1 columns]>

# %%
#split data into test and split at .80 (of )
y_train = df.iloc[:round(df.shape[0]*.80)]
y_test = df.iloc[round(df.shape[0]*.80):]

# %%
y_train.tail(10)
# Out:
#                   Close
# Date
# 2020-10-28  3162.780029
# 2020-10-29  3211.010010
# 2020-10-30  3036.149902
# 2020-11-02  3004.479980
# 2020-11-03  3048.409912
# 2020-11-04  3241.159912
# 2020-11-05  3322.000000
# 2020-11-06  3311.370117
# 2020-11-09  3143.739990
# 2020-11-10  3035.020020

# %%
y_test.head(10)
# Out:
#                   Close
# Date
# 2020-11-11  3137.389893
# 2020-11-12  3110.280029
# 2020-11-13  3128.810059
# 2020-11-16  3131.060059
# 2020-11-17  3135.659912
# 2020-11-18  3105.459961
# 2020-11-19  3117.020020
# 2020-11-20  3099.399902
# 2020-11-23  3098.389893
# 2020-11-24  3118.060059

# %%
#plot train and test
plt.figure(figsize=(16,8))
plt.plot(y_train, label='Train')
plt.plot(y_test, label='Actual')
plt.ylabel("Stock prices")
plt.title('MSFT Stock Prices',fontsize=20)
plt.show()

# %%
print("start:",y_test.index.min())
print("end:",y_test.index.max())
# Out:
# start: 2020-11-11 00:00:00
# end: 2021-04-30 00:00:00

# %%
y_test.shape
# Out:
# (117, 1)

# %%
y_train.shape
# Out:
# (470, 1)

# %%
arima = ARIMA(y_train,order=(6,1,1)).fit(disp=False)
y_arima = arima.predict(470,586,typ='levels')
y_arima.index = y_test.index
# Out:
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
#Check MSE of model
arima_mse = mse(y_arima,y_test)

mse(y_arima,y_test)
# Out:
# 20591.673572821324

# %%
arima_df = pd.DataFrame(y_arima)

arima_df
# Out:
#                       0
# Date
# 2020-11-11  3046.964860
# 2020-11-12  3053.945681
# 2020-11-13  3076.346568
# 2020-11-16  3073.649409
# 2020-11-17  3091.238087
# ...                 ...
# 2021-04-26  3435.958312
# 2021-04-27  3439.202263
# 2021-04-28  3442.446214
# 2021-04-29  3445.690164
# 2021-04-30  3448.934115
#
# [117 rows x 1 columns]

# %%
arima_df['Actual'] = y_test['Close'].values

arima_df
# Out:
#                       0       Actual
# Date
# 2020-11-11  3046.964860  3137.389893
# 2020-11-12  3053.945681  3110.280029
# 2020-11-13  3076.346568  3128.810059
# 2020-11-16  3073.649409  3131.060059
# 2020-11-17  3091.238087  3135.659912
# ...                 ...          ...
# 2021-04-26  3435.958312  3409.000000
# 2021-04-27  3439.202263  3417.429932
# 2021-04-28  3442.446214  3458.500000
# 2021-04-29  3445.690164  3471.310059
# 2021-04-30  3448.934115  3467.419922
#
# [117 rows x 2 columns]

# %%
arima_df.columns=['Forecasted', 'Actual']

arima_df
# Out:
#              Forecasted       Actual
# Date
# 2020-11-11  3046.964860  3137.389893
# 2020-11-12  3053.945681  3110.280029
# 2020-11-13  3076.346568  3128.810059
# 2020-11-16  3073.649409  3131.060059
# 2020-11-17  3091.238087  3135.659912
# ...                 ...          ...
# 2021-04-26  3435.958312  3409.000000
# 2021-04-27  3439.202263  3417.429932
# 2021-04-28  3442.446214  3458.500000
# 2021-04-29  3445.690164  3471.310059
# 2021-04-30  3448.934115  3467.419922
#
# [117 rows x 2 columns]

# %%
arima_df['MPE'] = np.mean((arima_df['Forecasted'] - arima_df['Actual'] )/arima_df['Actual']) 

arima_df
# Out:
#              Forecasted       Actual       MPE
# Date
# 2020-11-11  3046.964860  3137.389893  0.018537
# 2020-11-12  3053.945681  3110.280029  0.018537
# 2020-11-13  3076.346568  3128.810059  0.018537
# 2020-11-16  3073.649409  3131.060059  0.018537
# 2020-11-17  3091.238087  3135.659912  0.018537
# ...                 ...          ...       ...
# 2021-04-26  3435.958312  3409.000000  0.018537
# 2021-04-27  3439.202263  3417.429932  0.018537
# 2021-04-28  3442.446214  3458.500000  0.018537
# 2021-04-29  3445.690164  3471.310059  0.018537
# 2021-04-30  3448.934115  3467.419922  0.018537
#
# [117 rows x 3 columns]

# %%
#calculate MPE score

arima_mpe = np.mean(arima_df['MPE'])

arima_mpe
# Out:
# 0.018536680265850376

# %%
#Plot ARIMA model

plt.figure(figsize=(16,8))
plt.plot(y_train,label='Train')
plt.plot(y_test,label='Actual')
plt.plot(y_arima,label='ARIMA Predict')
plt.ylabel("Stock prices")
plt.title('AMZN ARIMA Model',fontsize=20)
#save fig
plt.savefig("ARIMA_AMZN.png",)

plt.show()

# %% [markdown]
# ## Checking ARMA Model

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
arma = ARMA(y_train,order=(1,1)).fit()
y_arma =arma.predict(470,586)
y_arma.index = y_test.index
# Out:
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
#Check MSE of model
arma_mse = mse(y_arma,y_test)

mse(y_arma,y_test)
# Out:
# 91320.97786161781

# %%
arma_df = pd.DataFrame(y_arma)

arma_df
# Out:
#                       0
# Date
# 2020-11-11  3039.947747
# 2020-11-12  3038.007371
# 2020-11-13  3036.071741
# 2020-11-16  3034.140844
# 2020-11-17  3032.214669
# ...                 ...
# 2021-04-26  2849.645203
# 2021-04-27  2848.170231
# 2021-04-28  2846.698866
# 2021-04-29  2845.231099
# 2021-04-30  2843.766922
#
# [117 rows x 1 columns]

# %%
arma_df['Actual'] = y_test['Close'].values

arma_df
# Out:
#                       0       Actual
# Date
# 2020-11-11  3039.947747  3137.389893
# 2020-11-12  3038.007371  3110.280029
# 2020-11-13  3036.071741  3128.810059
# 2020-11-16  3034.140844  3131.060059
# 2020-11-17  3032.214669  3135.659912
# ...                 ...          ...
# 2021-04-26  2849.645203  3409.000000
# 2021-04-27  2848.170231  3417.429932
# 2021-04-28  2846.698866  3458.500000
# 2021-04-29  2845.231099  3471.310059
# 2021-04-30  2843.766922  3467.419922
#
# [117 rows x 2 columns]

# %%
arma_df.columns=['Forecasted', 'Actual']

arma_df
# Out:
#              Forecasted       Actual
# Date
# 2020-11-11  3039.947747  3137.389893
# 2020-11-12  3038.007371  3110.280029
# 2020-11-13  3036.071741  3128.810059
# 2020-11-16  3034.140844  3131.060059
# 2020-11-17  3032.214669  3135.659912
# ...                 ...          ...
# 2021-04-26  2849.645203  3409.000000
# 2021-04-27  2848.170231  3417.429932
# 2021-04-28  2846.698866  3458.500000
# 2021-04-29  2845.231099  3471.310059
# 2021-04-30  2843.766922  3467.419922
#
# [117 rows x 2 columns]

# %%
arma_df['MPE'] = np.mean((arma_df['Forecasted'] - arma_df['Actual'] )/arma_df['Actual']) 

arma_df
# Out:
#              Forecasted       Actual       MPE
# Date
# 2020-11-11  3039.947747  3137.389893 -0.081904
# 2020-11-12  3038.007371  3110.280029 -0.081904
# 2020-11-13  3036.071741  3128.810059 -0.081904
# 2020-11-16  3034.140844  3131.060059 -0.081904
# 2020-11-17  3032.214669  3135.659912 -0.081904
# ...                 ...          ...       ...
# 2021-04-26  2849.645203  3409.000000 -0.081904
# 2021-04-27  2848.170231  3417.429932 -0.081904
# 2021-04-28  2846.698866  3458.500000 -0.081904
# 2021-04-29  2845.231099  3471.310059 -0.081904
# 2021-04-30  2843.766922  3467.419922 -0.081904
#
# [117 rows x 3 columns]

# %%
#calculate MPE score

arma_mpe = np.mean(arma_df['MPE'])

arma_mpe
# Out:
# -0.08190413183606611

# %%
plt.figure(figsize=(16,8))
plt.plot(y_train,label='Train')
plt.plot(y_test,label='Actual')
plt.plot(y_arma,label='ARIMA Predict')
plt.ylabel("Stock prices")
plt.title('AMZN ARMA Model',fontsize=20)
#save fig
plt.savefig("ARMA_AMZN.png",)

plt.show()

# %% [markdown]
# ### Visualize results

# %%
mse_df = pd.DataFrame({'Ticker':['AMZN', 'AMZN'],
                       'Model':['ARIMA', 'ARMA'],
                    'MSE Score':[arima_mse, arma_mse,],   
                    'MPE Score':[arima_mpe, arma_mpe]})
                   
mse_df
# Out:
#   Ticker  Model     MSE Score  MPE Score
# 0   AMZN  ARIMA  20591.673573   0.018537
# 1   AMZN   ARMA  91320.977862  -0.081904

# %%
#export MSE table

mse_df.to_csv('AMZN_MSE.csv')
