# %%
pip install -u pandas-datareader
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] <requirement specifier> [package-index-options] ...
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] -r <requirements file> [package-index-options] ...
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] [-e] <vcs project url> ...
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] [-e] <local project path> ...
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] <archive url/path> ...
#
# no such option: -u

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from statsmodels) (1.19.5)
# Requirement already satisfied: scipy>=1.1 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from statsmodels) (1.5.2)
# Requirement already satisfied: pandas>=0.21 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from statsmodels) (1.1.3)
# Requirement already satisfied: patsy>=0.5 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pandas>=0.21->statsmodels) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: six in c:\users\dan.marks\appdata\roaming\python\python37\site-packages (from patsy>=0.5->statsmodels) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import librarys
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import os
import time
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse
plt.style.use('seaborn')

# %% [markdown]
# ## Getting Data from Yahoo Finance

# %%
#get Microsoft stock price
msftdf = web.DataReader('msft', data_source='yahoo', start='2018-05-01', end='2021-05-01')

msftdf
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-05-01   95.290001   92.790001   93.209999   95.000000  31408900.0
# 2018-05-02   95.169998   93.190002   94.989998   93.510002  27471000.0
# 2018-05-03   94.930000   92.449997   92.959999   94.070000  31142500.0
# 2018-05-04   95.370003   92.919998   93.320000   95.160004  22531300.0
# 2018-05-07   96.709999   95.099998   95.169998   96.220001  24242000.0
# ...                ...         ...         ...         ...         ...
# 2021-04-26  262.440002  260.170013  261.660004  261.549988  19763300.0
# 2021-04-27  263.190002  260.119995  261.579987  261.970001  31014200.0
# 2021-04-28  256.540009  252.949997  256.079987  254.559998  46903100.0
# 2021-04-29  256.100006  249.000000  255.460007  252.509995  40589000.0
# 2021-04-30  253.080002  249.600006  249.740005  252.179993  30929200.0
#
#              Adj Close
# Date
# 2018-05-01   91.275635
# 2018-05-02   89.844063
# 2018-05-03   90.382095
# 2018-05-04   91.429367
# 2018-05-07   92.447807
# ...                ...
# 2021-04-26  261.549988
# 2021-04-27  261.970001
# 2021-04-28  254.559998
# 2021-04-29  252.509995
# 2021-04-30  252.179993
#
# [756 rows x 6 columns]

# %%
#get Facebook stock price
fbdf = web.DataReader('FB', data_source='yahoo', start='2018-05-01', end='2021-05-01')

fbdf
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2018-05-01  174.020004  170.229996  172.000000  173.860001  26025900
# 2018-05-02  178.080002  174.199997  174.250000  176.070007  30424500
# 2018-05-03  176.119995  172.119995  175.130005  174.020004  24026100
# 2018-05-04  176.979996  173.059998  173.080002  176.610001  17677800
# 2018-05-07  179.500000  177.169998  177.350006  177.970001  18697200
# ...                ...         ...         ...         ...       ...
# 2021-04-26  305.799988  301.559998  303.339996  303.040009  16172600
# 2021-04-27  305.339996  301.109985  304.279999  303.570007  15309300
# 2021-04-28  310.920013  305.369995  307.359985  307.100006  33907200
# 2021-04-29  331.809998  321.609985  330.119995  329.510010  56526800
# 2021-04-30  329.820007  324.500000  326.140015  325.079987  26322000
#
#              Adj Close
# Date
# 2018-05-01  173.860001
# 2018-05-02  176.070007
# 2018-05-03  174.020004
# 2018-05-04  176.610001
# 2018-05-07  177.970001
# ...                ...
# 2021-04-26  303.040009
# 2021-04-27  303.570007
# 2021-04-28  307.100006
# 2021-04-29  329.510010
# 2021-04-30  325.079987
#
# [756 rows x 6 columns]

# %%
#get Apple stock price
aapldf = web.DataReader('AAPL', data_source='yahoo', start='2018-05-01', end='2021-05-01')

aapldf
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2018-05-01   42.299999   41.317501   41.602501   42.275002  214277600.0
# 2018-05-02   44.437500   43.450001   43.807499   44.142502  266157600.0
# 2018-05-03   44.375000   43.610001   43.970001   44.222500  136272800.0
# 2018-05-04   46.062500   44.542500   44.562500   45.957500  224805200.0
# 2018-05-07   46.917500   46.187500   46.294998   46.290001  169805600.0
# ...                ...         ...         ...         ...          ...
# 2021-04-26  135.059998  133.559998  134.830002  134.720001   66905100.0
# 2021-04-27  135.410004  134.110001  135.009995  134.389999   66015800.0
# 2021-04-28  135.020004  133.080002  134.309998  133.580002  107760100.0
# 2021-04-29  137.070007  132.449997  136.470001  133.479996  151101000.0
# 2021-04-30  133.559998  131.070007  131.779999  131.460007  109713200.0
#
#              Adj Close
# Date
# 2018-05-01   40.717613
# 2018-05-02   42.516315
# 2018-05-03   42.593361
# 2018-05-04   44.264439
# 2018-05-07   44.584698
# ...                ...
# 2021-04-26  134.491562
# 2021-04-27  134.162109
# 2021-04-28  133.353485
# 2021-04-29  133.253662
# 2021-04-30  131.237091
#
# [756 rows x 6 columns]

# %%
#get Google stock price
googdf = web.DataReader('GOOGL', data_source='yahoo', start='2018-05-01', end='2021-05-01')

googdf
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2018-05-01  1041.729980  1010.609985  1016.299988  1040.750000  1766300
# 2018-05-02  1043.979980  1023.159973  1034.000000  1026.050049  1734900
# 2018-05-03  1030.689941  1007.890015  1025.369995  1026.300049  1964100
# 2018-05-04  1051.880005  1018.049988  1019.609985  1051.000000  1844600
# 2018-05-07  1065.000000  1050.270020  1053.890015  1059.459961  1720000
# ...                 ...          ...          ...          ...      ...
# 2021-04-26  2324.530029  2297.320068  2304.520020  2309.929932  1601900
# 2021-04-27  2318.449951  2286.159912  2317.629883  2290.979980  2219300
# 2021-04-28  2431.379883  2353.219971  2392.500000  2359.040039  4055300
# 2021-04-29  2404.159912  2373.850098  2389.229980  2392.760010  2061700
# 2021-04-30  2381.850098  2346.560059  2368.020020  2353.500000  2242000
#
#               Adj Close
# Date
# 2018-05-01  1040.750000
# 2018-05-02  1026.050049
# 2018-05-03  1026.300049
# 2018-05-04  1051.000000
# 2018-05-07  1059.459961
# ...                 ...
# 2021-04-26  2309.929932
# 2021-04-27  2290.979980
# 2021-04-28  2359.040039
# 2021-04-29  2392.760010
# 2021-04-30  2353.500000
#
# [756 rows x 6 columns]

# %%
#get Amazon stock price
amzndf = web.DataReader('AMZN', data_source='yahoo', start='2018-05-01', end='2021-05-01')

amzndf
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2018-05-01  1585.000000  1552.180054  1563.219971  1582.260010  4572100
# 2018-05-02  1588.500000  1566.359985  1580.979980  1569.680054  4360300
# 2018-05-03  1574.800049  1546.020020  1560.010010  1572.079956  4251900
# 2018-05-04  1584.900024  1562.189941  1562.449951  1580.949951  3443600
# 2018-05-07  1606.949951  1587.829956  1589.339966  1600.140015  3801900
# ...                 ...          ...          ...          ...      ...
# 2021-04-26  3428.449951  3330.939941  3348.000000  3409.000000  4880700
# 2021-04-27  3460.000000  3398.010010  3443.469971  3417.429932  3827100
# 2021-04-28  3489.879883  3425.000000  3434.800049  3458.500000  4631900
# 2021-04-29  3514.449951  3435.000000  3505.100098  3471.310059  7682400
# 2021-04-30  3554.000000  3462.500000  3525.120117  3467.419922  7001800
#
#               Adj Close
# Date
# 2018-05-01  1582.260010
# 2018-05-02  1569.680054
# 2018-05-03  1572.079956
# 2018-05-04  1580.949951
# 2018-05-07  1600.140015
# ...                 ...
# 2021-04-26  3409.000000
# 2021-04-27  3417.429932
# 2021-04-28  3458.500000
# 2021-04-29  3471.310059
# 2021-04-30  3467.419922
#
# [756 rows x 6 columns]

# %% [markdown]
# ## Visualizing the Data

# %%
#plot close prices
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(msftdf['Close'], label='MSFT')
plt.plot(fbdf['Close'], label='FB')
plt.plot(aapldf['Close'], label='AAPL')
plt.plot(googdf['Close'], label='GOOGL')
plt.plot(amzndf['Close'], label='AMZN')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.title('Volume History')
plt.plot(msftdf['Volume'], label='MSFT')
plt.plot(fbdf['Volume'], label='FB')
plt.plot(aapldf['Volume'], label='AAPL')
plt.plot(googdf['Volume'], label='GOOGL')
plt.plot(amzndf['Volume'], label='AMZN')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.legend()

# %%
#creating new column = 'Total Traded' which is close price * volume

# %%
msftdf['Total Traded'] = msftdf['Close']*msftdf['Volume']
fbdf['Total Traded'] = fbdf['Close']*fbdf['Volume']
aapldf['Total Traded'] = aapldf['Close']*aapldf['Volume']
amzndf['Total Traded'] = amzndf['Close']*amzndf['Volume']
googdf['Total Traded'] = googdf['Close']*googdf['Volume']

# %%
plt.figure(figsize=(16,8))
plt.title('Total Traded History')
plt.plot(msftdf['Total Traded'], label='MSFT')
plt.plot(fbdf['Total Traded'], label='FB')
plt.plot(aapldf['Total Traded'], label='AAPL')
plt.plot(googdf['Total Traded'], label='GOOGL')
plt.plot(amzndf['Total Traded'], label='AMZN')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.legend()

# %% [markdown]
# ## Getting started with ARIMA

# %% [markdown]
# ##### First ARIMA model without splitting data

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA

# %%
#check length of df
len(msftdf)
# Out:
# 756

# %%
#making arima model with pdq as 1,1,1 without fitting data

model = ARIMA(msftdf['Close'].fillna(value=msftdf['Close'].mean()),order=(6,1,6))
model_fit= model.fit()
model_fit.params
result= model.fit(disp=False)
# Out:
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  755
# Model:                 ARIMA(6, 1, 6)   Log Likelihood               -1904.881
# Method:                       css-mle   S.D. of innovations              3.015
# Date:                Fri, 14 May 2021   AIC                           3837.762
# Time:                        22:23:51   BIC                           3902.536
# Sample:                             1   HQIC                          3862.713
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.2083      0.092      2.259      0.024       0.028       0.389
# ar.L1.D.Close     0.1181      0.153      0.771      0.441      -0.182       0.418
# ar.L2.D.Close     0.3870      0.215      1.800      0.072      -0.034       0.808
# ar.L3.D.Close    -0.6680      0.140     -4.766      0.000      -0.943      -0.393
# ar.L4.D.Close    -0.2430      0.163     -1.494      0.135      -0.562       0.076
# ar.L5.D.Close     0.1203      0.162      0.742      0.458      -0.197       0.438
# ar.L6.D.Close    -0.5345      0.158     -3.388      0.001      -0.844      -0.225
# ma.L1.D.Close    -0.3713      0.152     -2.444      0.015      -0.669      -0.074
# ma.L2.D.Close    -0.2890      0.207     -1.399      0.162      -0.694       0.116
# ma.L3.D.Close     0.7987      0.170      4.704      0.000       0.466       1.131
# ma.L4.D.Close     0.0125      0.140      0.089      0.929      -0.261       0.286
# ma.L5.D.Close    -0.1520      0.161     -0.943      0.345      -0.468       0.164
# ma.L6.D.Close     0.5310      0.103      5.146      0.000       0.329       0.733
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.9674           -0.3910j            1.0434           -0.4389
# AR.2           -0.9674           +0.3910j            1.0434            0.4389
# AR.3            0.8208           -0.6031j            1.0185           -0.1009
# AR.4            0.8208           +0.6031j            1.0185            0.1009
# AR.5            0.2591           -1.2607j            1.2871           -0.2177
# AR.6            0.2591           +1.2607j            1.2871            0.2177
# MA.1           -1.0326           -0.3953j            1.1057           -0.4418
# MA.2           -1.0326           +0.3953j            1.1057            0.4418
# MA.3            0.8350           -0.5895j            1.0221           -0.0978
# MA.4            0.8350           +0.5895j            1.0221            0.0978
# MA.5            0.3407           -1.1655j            1.2143           -0.2047
# MA.6            0.3407           +1.1655j            1.2143            0.2047
# -----------------------------------------------------------------------------
# """

# %%
#use ARIMA predict function to apply predictions to variable = y_predict
y_predict = model_fit.predict(typ='levels')
print(y_predict)
# Out:
# Date
# 2018-05-02     95.208305
# 2018-05-03     94.188996
# 2018-05-04     94.157542
# 2018-05-07     95.069710
# 2018-05-08     96.263212
#                  ...
# 2021-04-26    260.206703
# 2021-04-27    261.612768
# 2021-04-28    262.373893
# 2021-04-29    256.722719
# 2021-04-30    253.517037
# Length: 755, dtype: float64

# %%
msftdf['forecast']= model_fit.predict(start=604,typ='levels')
msftdf[['Close', 'forecast']].plot(figsize=(16,8))
plt.show()

# %%
#check MSE score
nosplit_mse = mean_squared_error(msftdf['Close'][1:len(msftdf)],y_predict)

mean_squared_error(msftdf['Close'][1:len(msftdf)],y_predict)
# Out:
# 9.089354901044867

# %% [markdown]
# ###### ARIMA with split of y_train and y_test

# %%
#get close data alone

msftdf = msftdf[['Close']].copy()
msftdf.info
# Out:
# <bound method DataFrame.info of                  Close
# Date
# 2018-05-01   95.000000
# 2018-05-02   93.510002
# 2018-05-03   94.070000
# 2018-05-04   95.160004
# 2018-05-07   96.220001
# ...                ...
# 2021-04-26  261.549988
# 2021-04-27  261.970001
# 2021-04-28  254.559998
# 2021-04-29  252.509995
# 2021-04-30  252.179993
#
# [756 rows x 1 columns]>

# %%
#split data into test and split at .80 (of )
y_train = msftdf.iloc[:604]
y_test = msftdf.iloc[604:]

# %%
y_train.tail()
# Out:
#                  Close
# Date
# 2020-09-16  205.050003
# 2020-09-17  202.910004
# 2020-09-18  200.389999
# 2020-09-21  202.539993
# 2020-09-22  207.419998

# %%
y_test.head()
# Out:
#                  Close
# Date
# 2020-09-23  200.589996
# 2020-09-24  203.190002
# 2020-09-25  207.820007
# 2020-09-28  209.440002
# 2020-09-29  207.259995

# %%
#plot train and test
plt.figure(figsize=(16,8))
plt.plot(y_train,label='Train')
plt.plot(y_test,label='Actual')
plt.ylabel("Stock prices")
plt.title('MSFT Stock Prices',fontsize=20)
#save fig
plt.savefig("notfit_ARIMA_MSFT.png",)

plt.show()

# %%
print("start:",y_test.index.min())
print("end:",y_test.index.max())
# Out:
# start: 2020-09-23 00:00:00
# end: 2021-04-30 00:00:00

# %%
y_test.shape
# Out:
# (152, 1)

# %%
y_train.shape
# Out:
# (604, 1)

# %%
arima = ARIMA(y_train,order=(1,1,1)).fit(disp=False)
y_arima = arima.predict(604,755,typ='levels')
y_arima.index = y_test.index
# Out:
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
#Check MSE of model
arima_mse = mse(y_arima,y_test)

mse(y_arima,y_test)
# Out:
# 134.26755834668572

# %%
#Plot ARIMA model

plt.figure(figsize=(16,8))
plt.plot(y_train,label='Train')
plt.plot(y_test,label='Actual')
plt.plot(y_arima,label='ARIMA Predict')
plt.ylabel("Stock prices")
plt.title('ARIMA Model',fontsize=20)
#save fig
plt.savefig("ARIMA_MSFT.png",)

plt.show()

# %% [markdown]
# ## Checking ARMA Model

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
arma = ARMA(y_train,order=(1,1)).fit()
y_arma =arma.predict(604,755)
y_arma.index = y_test.index
# Out:
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
#Check MSE of model
mse(y_arma,y_test)

arma_mse = mse(y_arma,y_test)

# %%
plt.figure(figsize=(16,8))
plt.plot(y_train,label='Train')
plt.plot(y_test,label='Actual')
plt.plot(y_arma,label='ARIMA Predict')
plt.ylabel("Stock prices")
plt.title('ARIMA Model',fontsize=20)
#save fig
plt.savefig("ARMA_MSFT.png",)

plt.show()

# %% [markdown]
# ### Visualize results

# %%
import pandas as pd

# %%
mse_df = DataFrame[nosplit_mse, arima_mse, arma_mse]

mse_df.head()

# %%
df = pd.Dataframe({'Ticker':['MSFT', 'MSFT', 'MSFT'],
                       'Model':['No Split', 'Arima', 'ARMA'],
                    'MSE Score':[nosplit_mse, arima_mse, arma_mse],})
                   
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-a70d75d28a56> in <module>
# ----> 1 df = pd.Dataframe({'Ticker':['MSFT', 'MSFT', 'MSFT'],
#       2                        'Model':['No Split', 'Arima', 'ARMA'],
#       3                     'MSE Score':[nosplit_mse, arima_mse, arma_mse],})
#       4
#       5 df
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'
