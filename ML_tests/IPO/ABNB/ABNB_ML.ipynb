# %% [markdown]
# ### First some pip installs you may need to run code

# %%
pip install -u pandas-datareader
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] <requirement specifier> [package-index-options] ...
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] -r <requirements file> [package-index-options] ...
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] [-e] <vcs project url> ...
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] [-e] <local project path> ...
#   C:\Users\dan.marks\Anaconda3\envs\mlenv\python.exe -m pip install [options] <archive url/path> ...
#
# no such option: -u

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from statsmodels) (1.19.5)
# Requirement already satisfied: scipy>=1.1 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from statsmodels) (1.5.2)
# Requirement already satisfied: pandas>=0.21 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from statsmodels) (1.1.3)
# Requirement already satisfied: patsy>=0.5 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pandas>=0.21->statsmodels) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: six in c:\users\dan.marks\appdata\roaming\python\python37\site-packages (from patsy>=0.5->statsmodels) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (1.8.2)
# Requirement already satisfied: urllib3 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pmdarima) (1.25.11)
# Requirement already satisfied: joblib>=0.11 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pmdarima) (0.17.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pmdarima) (50.3.1.post20201107)
# Requirement already satisfied: pandas>=0.19 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pmdarima) (1.1.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pmdarima) (0.24.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pmdarima) (0.29.21)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: numpy~=1.19.0 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pandas>=0.19->pmdarima) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\dan.marks\anaconda3\envs\mlenv\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\dan.marks\appdata\roaming\python\python37\site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import librarys
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import os
import time
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse
plt.style.use('seaborn')

# %% [markdown]
# ## Getting Data from Yahoo Finance

# %%
#get moderna stock price
mrnadf = web.DataReader('mrna', data_source='yahoo', start='2019-01-01', end='2021-05-01')

mrnadf
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-01-02   15.450000   14.510000   14.930000   15.330000   2318100
# 2019-01-03   16.080000   15.200000   15.490000   15.500000   1588900
# 2019-01-04   17.500000   15.894000   16.000000   16.959999   1651800
# 2019-01-07   17.940001   16.180000   17.540001   16.270000   1585400
# 2019-01-08   17.468000   16.049999   17.350000   16.950001   1892700
# ...                ...         ...         ...         ...       ...
# 2021-04-26  179.600006  168.880005  171.789993  177.610001  12201700
# 2021-04-27  185.529999  178.179993  178.360001  183.410004  12925700
# 2021-04-28  182.889999  176.119995  182.369995  178.679993   8375400
# 2021-04-29  186.800003  174.759995  183.326996  175.669998   8362700
# 2021-04-30  184.000000  174.520004  175.589996  178.820007   9469100
#
#              Adj Close
# Date
# 2019-01-02   15.330000
# 2019-01-03   15.500000
# 2019-01-04   16.959999
# 2019-01-07   16.270000
# 2019-01-08   16.950001
# ...                ...
# 2021-04-26  177.610001
# 2021-04-27  183.410004
# 2021-04-28  178.679993
# 2021-04-29  175.669998
# 2021-04-30  178.820007
#
# [587 rows x 6 columns]

# %%
#get ABNB stock price
abnbdf = web.DataReader('ABNB', data_source='yahoo', start='2019-01-01', end='2021-05-01')

abnbdf
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-12-10  165.000000  141.250000  146.000000  144.710007  70447500
# 2020-12-11  151.500000  135.100006  146.550003  139.250000  26980800
# 2020-12-14  135.300003  125.160004  135.000000  130.000000  16966100
# 2020-12-15  127.599998  121.500000  126.690002  124.800003  10914400
# 2020-12-16  142.000000  124.910004  125.830002  137.990005  20409600
# ...                ...         ...         ...         ...       ...
# 2021-04-26  176.031006  171.070007  175.210007  174.880005   2549400
# 2021-04-27  179.610001  174.800003  176.164993  177.940002   2883000
# 2021-04-28  181.669998  173.350998  174.436996  180.000000   2409700
# 2021-04-29  183.220001  173.350006  182.750000  177.679993   3116000
# 2021-04-30  176.449997  172.009995  173.003998  172.710007   3569700
#
#              Adj Close
# Date
# 2020-12-10  144.710007
# 2020-12-11  139.250000
# 2020-12-14  130.000000
# 2020-12-15  124.800003
# 2020-12-16  137.990005
# ...                ...
# 2021-04-26  174.880005
# 2021-04-27  177.940002
# 2021-04-28  180.000000
# 2021-04-29  177.679993
# 2021-04-30  172.710007
#
# [97 rows x 6 columns]

# %%
#get ZOOM stock price
zmdf = web.DataReader('ZM', data_source='yahoo', start='2019-01-01', end='2021-05-01')

zmdf
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-04-18   66.000000   60.320999   65.000000   62.000000  25764700
# 2019-04-22   68.900002   59.939999   61.000000   65.699997   9949700
# 2019-04-23   74.168999   65.550003   66.870003   69.000000   6786500
# 2019-04-24   71.500000   63.160000   71.400002   63.200001   4973500
# 2019-04-25   66.849998   62.599998   64.739998   65.000000   3863300
# ...                ...         ...         ...         ...       ...
# 2021-04-26  338.000000  329.209991  337.510010  336.420013   2286700
# 2021-04-27  341.679993  330.890015  336.390015  333.489990   2208300
# 2021-04-28  334.700989  326.045013  330.239990  331.250000   1437600
# 2021-04-29  332.500000  318.890015  331.160004  321.100006   3121100
# 2021-04-30  326.278992  317.239990  318.029999  319.570007   2147200
#
#              Adj Close
# Date
# 2019-04-18   62.000000
# 2019-04-22   65.699997
# 2019-04-23   69.000000
# 2019-04-24   63.200001
# 2019-04-25   65.000000
# ...                ...
# 2021-04-26  336.420013
# 2021-04-27  333.489990
# 2021-04-28  331.250000
# 2021-04-29  321.100006
# 2021-04-30  319.570007
#
# [513 rows x 6 columns]

# %%
#get CRWD stock price
crwddf = web.DataReader('CRWD', data_source='yahoo', start='2019-01-01', end='2021-05-01')

crwddf
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-06-12   67.000000   56.000000   63.500000   58.000000  19449200
# 2019-06-13   69.669998   61.599998   63.860001   67.559998  10923900
# 2019-06-14   70.790001   63.020000   69.779999   64.160004   6264200
# 2019-06-17   70.010002   62.000000   64.750000   70.010002   3247500
# 2019-06-18   78.699997   71.500000   73.000000   76.500000   6612600
# ...                ...         ...         ...         ...       ...
# 2021-04-26  225.100006  215.929993  220.050003  224.470001   3614600
# 2021-04-27  227.199997  219.891006  225.479996  221.250000   2326700
# 2021-04-28  223.259995  215.022995  217.869995  220.240005   2486600
# 2021-04-29  221.000000  208.419998  221.000000  211.529999   3322300
# 2021-04-30  214.350006  207.000000  207.334000  208.509995   2027400
#
#              Adj Close
# Date
# 2019-06-12   58.000000
# 2019-06-13   67.559998
# 2019-06-14   64.160004
# 2019-06-17   70.010002
# 2019-06-18   76.500000
# ...                ...
# 2021-04-26  224.470001
# 2021-04-27  221.250000
# 2021-04-28  220.240005
# 2021-04-29  211.529999
# 2021-04-30  208.509995
#
# [476 rows x 6 columns]

# %%
#get DOCU stock price
docudf = web.DataReader('DOCU', data_source='yahoo', start='2019-01-01', end='2021-05-01')

docudf
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2019-01-02   40.830002   39.139999   39.270000   40.820000  1674300
# 2019-01-03   40.520000   38.799999   40.000000   38.830002   986900
# 2019-01-04   41.415001   39.419998   39.520000   40.900002  1852600
# 2019-01-07   42.200001   39.500000   40.040001   41.689999  2630900
# 2019-01-08   42.320000   40.931000   41.959999   42.080002  3192600
# ...                ...         ...         ...         ...      ...
# 2021-04-26  234.440002  223.681000  225.399994  234.360001  2255600
# 2021-04-27  234.729996  228.500000  234.009995  230.020004  1355600
# 2021-04-28  236.106995  227.164001  227.425003  232.300003  1584900
# 2021-04-29  232.889999  221.500000  232.889999  224.589996  1622700
# 2021-04-30  228.360001  220.619995  221.089996  222.940002  1288300
#
#              Adj Close
# Date
# 2019-01-02   40.820000
# 2019-01-03   38.830002
# 2019-01-04   40.900002
# 2019-01-07   41.689999
# 2019-01-08   42.080002
# ...                ...
# 2021-04-26  234.360001
# 2021-04-27  230.020004
# 2021-04-28  232.300003
# 2021-04-29  224.589996
# 2021-04-30  222.940002
#
# [587 rows x 6 columns]

# %% [markdown]
# ## Visualizing the Data

# %%
#plot close prices
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(abnbdf['Close'], label='ABNB')
plt.plot(zmdf['Close'], label='ZM')
plt.plot(mrnadf['Close'], label='MRNA')
plt.plot(crwddf['Close'], label='CRWD')
plt.plot(docudf['Close'], label='DOCU')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.legend()

# %%
plt.figure(figsize=(16,8))
plt.title('Volume History')
plt.plot(abnbdf['Volume'], label='ABNB')
plt.plot(zmdf['Volume'], label='ZM')
plt.plot(mrnadf['Volume'], label='MRNA')
plt.plot(crwddf['Volume'], label='CRWD')
plt.plot(docudf['Volume'], label='DOCU')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.legend()

# %%
#creating new column = 'Total Traded' which is close price * volume

# %%
abnbdf['Total Traded'] = abnbdf['Close']*abnbdf['Volume']
zmdf['Total Traded'] = zmdf['Close']*zmdf['Volume']
mrnadf['Total Traded'] = mrnadf['Close']*mrnadf['Volume']
crwddf['Total Traded'] = crwddf['Close']*crwddf['Volume']
docudf['Total Traded'] = docudf['Close']*docudf['Volume']

# %%
plt.figure(figsize=(16,8))
plt.title('Total Traded History')
plt.plot(abnbdf['Total Traded'], label='ABNB')
plt.plot(zmdf['Total Traded'], label='ZM')
plt.plot(mrnadf['Total Traded'], label='MRNA')
plt.plot(crwddf['Total Traded'], label='CRWD')
plt.plot(docudf['Total Traded'], label='DOCU')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD($)', fontsize=18)
plt.legend()

# %% [markdown]
# ##### Before we look at 1 stock change 'ticker'df name to be df so code is reusable with minimal changes

# %%
# INPUT TICKER DF TO BE CHANGED TO 'df' for future code!
df = abnbdf

# %%
df
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-12-10  165.000000  141.250000  146.000000  144.710007  70447500
# 2020-12-11  151.500000  135.100006  146.550003  139.250000  26980800
# 2020-12-14  135.300003  125.160004  135.000000  130.000000  16966100
# 2020-12-15  127.599998  121.500000  126.690002  124.800003  10914400
# 2020-12-16  142.000000  124.910004  125.830002  137.990005  20409600
# ...                ...         ...         ...         ...       ...
# 2021-04-26  176.031006  171.070007  175.210007  174.880005   2549400
# 2021-04-27  179.610001  174.800003  176.164993  177.940002   2883000
# 2021-04-28  181.669998  173.350998  174.436996  180.000000   2409700
# 2021-04-29  183.220001  173.350006  182.750000  177.679993   3116000
# 2021-04-30  176.449997  172.009995  173.003998  172.710007   3569700
#
#              Adj Close  Total Traded
# Date
# 2020-12-10  144.710007  1.019446e+10
# 2020-12-11  139.250000  3.757076e+09
# 2020-12-14  130.000000  2.205593e+09
# 2020-12-15  124.800003  1.362117e+09
# 2020-12-16  137.990005  2.816321e+09
# ...                ...           ...
# 2021-04-26  174.880005  4.458391e+08
# 2021-04-27  177.940002  5.130010e+08
# 2021-04-28  180.000000  4.337460e+08
# 2021-04-29  177.679993  5.536509e+08
# 2021-04-30  172.710007  6.165229e+08
#
# [97 rows x 7 columns]

# %% [markdown]
# ## Take a look at the Data!

# %%
from statsmodels.tsa.stattools import adfuller
#ADF test will tell us if model is stationary. If p-value is greater than .05 we can conclude it is not stationary

result = adfuller(df.Close.dropna())
print(f"ADF Statistic: {result[0]}")
print(f"p-value: {result[1]}")
# Out:
# ADF Statistic: -2.2335125139431544
# p-value: 0.19430789924124436

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,4))

ax1.plot(df.Close)
ax1.set_title('Original')
plot_acf(df.Close, ax=ax2);

# %%
# check if we difference once

diff = df.Close.diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,4))

ax1.plot(diff)
ax1.set_title("Difference once")
plot_acf(diff, ax=ax2);

# %% [markdown]
# ##### We can conclude the data how many times the data should be differenced by the longest line in the auto correlation

# %%
from pmdarima.arima.utils import ndiffs

# %%
#another function to double check # of difference
ndiffs(df.Close, test='adf')
# Out:
# 1

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
diff = df.Close.diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,4))

ax1.plot(diff)
ax1.set_title("Difference once")
ax2.set_ylim(0, 1)
plot_pacf(diff, ax=ax2);

#we see 1 can be used as p term

# %%
#Finding q. q is order of the moving average. The # of lagged forecast errors that should go into ARIMA model

# %%
diff = df.Close.diff().dropna()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,4))

ax1.plot(diff)
ax1.set_title("Difference once")
ax2.set_ylim(0,1)
plot_acf(diff, ax=ax2);

#we can see our q term could be 1

# %% [markdown]
# ## Getting started with ARIMA

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# ### ARIMA with split of y_train and y_test

# %%
#get close data alone

df = df[['Close']].copy()
df.info
# Out:
# <bound method DataFrame.info of                  Close
# Date
# 2020-12-10  144.710007
# 2020-12-11  139.250000
# 2020-12-14  130.000000
# 2020-12-15  124.800003
# 2020-12-16  137.990005
# ...                ...
# 2021-04-26  174.880005
# 2021-04-27  177.940002
# 2021-04-28  180.000000
# 2021-04-29  177.679993
# 2021-04-30  172.710007
#
# [97 rows x 1 columns]>

# %%
#split data into test and split at .80 (of )
y_train = df.iloc[:round(df.shape[0]*.80)]
y_test = df.iloc[round(df.shape[0]*.80):]

# %%
y_train.shape
# Out:
# (78, 1)

# %%
y_test.shape
# Out:
# (19, 1)

# %%
#plot train and test
plt.figure(figsize=(16,8))
plt.plot(y_train, label='Train')
plt.plot(y_test, label='Actual')
plt.ylabel("Stock prices")
plt.title('ABNB Stock Prices',fontsize=20)
plt.show()

# %%
print("start:",y_test.index.min())
print("end:",y_test.index.max())
# Out:
# start: 2021-04-06 00:00:00
# end: 2021-04-30 00:00:00

# %%
y_test.shape
# Out:
# (19, 1)

# %%
y_train.shape
# Out:
# (78, 1)

# %%
arima = ARIMA(y_train,order=(1,1,1)).fit(disp=False)
y_arima = arima.predict(78,96,typ='levels')
y_arima.index = y_test.index
# Out:
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
#Check MSE of model
arima_mse = mse(y_arima,y_test)

mse(y_arima,y_test)
# Out:
# 291.0752921994788

# %%
arima_df = pd.DataFrame(y_arima)

arima_df
# Out:
#                      0
# Date
# 2021-04-06  187.205003
# 2021-04-07  187.777731
# 2021-04-08  188.310496
# 2021-04-09  188.870926
# 2021-04-12  189.412204
# 2021-04-13  189.966741
# 2021-04-14  190.512099
# 2021-04-15  191.063812
# 2021-04-16  191.611125
# 2021-04-19  192.161484
# 2021-04-20  192.709734
# 2021-04-21  193.259444
# 2021-04-22  193.808144
# 2021-04-23  194.357543
# 2021-04-26  194.906457
# 2021-04-27  195.455707
# 2021-04-28  196.004725
# 2021-04-29  196.553904
# 2021-04-30  197.102971

# %%
arima_df['Actual'] = y_test['Close'].values

arima_df
# Out:
#                      0      Actual
# Date
# 2021-04-06  187.205003  190.029999
# 2021-04-07  187.777731  179.940002
# 2021-04-08  188.310496  180.179993
# 2021-04-09  188.870926  179.500000
# 2021-04-12  189.412204  176.490005
# 2021-04-13  189.966741  177.949997
# 2021-04-14  190.512099  176.429993
# 2021-04-15  191.063812  175.350006
# 2021-04-16  191.611125  178.690002
# 2021-04-19  192.161484  174.580002
# 2021-04-20  192.709734  169.570007
# 2021-04-21  193.259444  167.070007
# 2021-04-22  193.808144  170.710007
# 2021-04-23  194.357543  174.250000
# 2021-04-26  194.906457  174.880005
# 2021-04-27  195.455707  177.940002
# 2021-04-28  196.004725  180.000000
# 2021-04-29  196.553904  177.679993
# 2021-04-30  197.102971  172.710007

# %%
arima_df.columns=['Forecasted', 'Actual']

arima_df
# Out:
#             Forecasted      Actual
# Date
# 2021-04-06  187.205003  190.029999
# 2021-04-07  187.777731  179.940002
# 2021-04-08  188.310496  180.179993
# 2021-04-09  188.870926  179.500000
# 2021-04-12  189.412204  176.490005
# 2021-04-13  189.966741  177.949997
# 2021-04-14  190.512099  176.429993
# 2021-04-15  191.063812  175.350006
# 2021-04-16  191.611125  178.690002
# 2021-04-19  192.161484  174.580002
# 2021-04-20  192.709734  169.570007
# 2021-04-21  193.259444  167.070007
# 2021-04-22  193.808144  170.710007
# 2021-04-23  194.357543  174.250000
# 2021-04-26  194.906457  174.880005
# 2021-04-27  195.455707  177.940002
# 2021-04-28  196.004725  180.000000
# 2021-04-29  196.553904  177.679993
# 2021-04-30  197.102971  172.710007

# %%
arima_df['MPE'] = np.mean((arima_df['Forecasted'] - arima_df['Actual'] )/arima_df['Actual']) 

arima_df
# Out:
#             Forecasted      Actual       MPE
# Date
# 2021-04-06  187.205003  190.029999  0.089603
# 2021-04-07  187.777731  179.940002  0.089603
# 2021-04-08  188.310496  180.179993  0.089603
# 2021-04-09  188.870926  179.500000  0.089603
# 2021-04-12  189.412204  176.490005  0.089603
# 2021-04-13  189.966741  177.949997  0.089603
# 2021-04-14  190.512099  176.429993  0.089603
# 2021-04-15  191.063812  175.350006  0.089603
# 2021-04-16  191.611125  178.690002  0.089603
# 2021-04-19  192.161484  174.580002  0.089603
# 2021-04-20  192.709734  169.570007  0.089603
# 2021-04-21  193.259444  167.070007  0.089603
# 2021-04-22  193.808144  170.710007  0.089603
# 2021-04-23  194.357543  174.250000  0.089603
# 2021-04-26  194.906457  174.880005  0.089603
# 2021-04-27  195.455707  177.940002  0.089603
# 2021-04-28  196.004725  180.000000  0.089603
# 2021-04-29  196.553904  177.679993  0.089603
# 2021-04-30  197.102971  172.710007  0.089603

# %%
#calculate MPE score

arima_mpe = np.mean(arima_df['MPE'])

arima_mpe
# Out:
# 0.08960332989189615

# %%
#Plot ARIMA model

plt.figure(figsize=(16,8))
plt.plot(y_train,label='Train')
plt.plot(y_test,label='Actual')
plt.plot(y_arima,label='ARIMA Predict')
plt.ylabel("Stock prices")
plt.title('MRNA ARIMA Model',fontsize=20)
#save fig
plt.savefig("ARIMA_MRNA.png",)

plt.show()

# %% [markdown]
# ## Checking ARMA Model

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
arma = ARMA(y_train,order=(1,1)).fit()
y_arma =arma.predict(78,96)
y_arma.index = y_test.index
# Out:
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\dan.marks\Anaconda3\envs\mlenv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
#Check MSE of model
arma_mse = mse(y_arma,y_test)

mse(y_arma,y_test)
# Out:
# 42.34409645785027

# %%
arma_df = pd.DataFrame(y_arma)

arma_df
# Out:
#                      0
# Date
# 2021-04-06  186.054598
# 2021-04-07  185.406153
# 2021-04-08  184.793377
# 2021-04-09  184.214306
# 2021-04-12  183.667089
# 2021-04-13  183.149971
# 2021-04-14  182.661298
# 2021-04-15  182.199505
# 2021-04-16  181.763113
# 2021-04-19  181.350725
# 2021-04-20  180.961022
# 2021-04-21  180.592754
# 2021-04-22  180.244743
# 2021-04-23  179.915875
# 2021-04-26  179.605096
# 2021-04-27  179.311412
# 2021-04-28  179.033883
# 2021-04-29  178.771619
# 2021-04-30  178.523782

# %%
arma_df['Actual'] = y_test['Close'].values

arma_df
# Out:
#                      0      Actual
# Date
# 2021-04-06  186.054598  190.029999
# 2021-04-07  185.406153  179.940002
# 2021-04-08  184.793377  180.179993
# 2021-04-09  184.214306  179.500000
# 2021-04-12  183.667089  176.490005
# 2021-04-13  183.149971  177.949997
# 2021-04-14  182.661298  176.429993
# 2021-04-15  182.199505  175.350006
# 2021-04-16  181.763113  178.690002
# 2021-04-19  181.350725  174.580002
# 2021-04-20  180.961022  169.570007
# 2021-04-21  180.592754  167.070007
# 2021-04-22  180.244743  170.710007
# 2021-04-23  179.915875  174.250000
# 2021-04-26  179.605096  174.880005
# 2021-04-27  179.311412  177.940002
# 2021-04-28  179.033883  180.000000
# 2021-04-29  178.771619  177.679993
# 2021-04-30  178.523782  172.710007

# %%
arma_df.columns=['Forecasted', 'Actual']

arma_df
# Out:
#             Forecasted      Actual
# Date
# 2021-04-06  186.054598  190.029999
# 2021-04-07  185.406153  179.940002
# 2021-04-08  184.793377  180.179993
# 2021-04-09  184.214306  179.500000
# 2021-04-12  183.667089  176.490005
# 2021-04-13  183.149971  177.949997
# 2021-04-14  182.661298  176.429993
# 2021-04-15  182.199505  175.350006
# 2021-04-16  181.763113  178.690002
# 2021-04-19  181.350725  174.580002
# 2021-04-20  180.961022  169.570007
# 2021-04-21  180.592754  167.070007
# 2021-04-22  180.244743  170.710007
# 2021-04-23  179.915875  174.250000
# 2021-04-26  179.605096  174.880005
# 2021-04-27  179.311412  177.940002
# 2021-04-28  179.033883  180.000000
# 2021-04-29  178.771619  177.679993
# 2021-04-30  178.523782  172.710007

# %%
arma_df['MPE'] = np.mean((arma_df['Forecasted'] - arma_df['Actual'] )/arma_df['Actual']) 

arma_df
# Out:
#             Forecasted      Actual       MPE
# Date
# 2021-04-06  186.054598  190.029999  0.029854
# 2021-04-07  185.406153  179.940002  0.029854
# 2021-04-08  184.793377  180.179993  0.029854
# 2021-04-09  184.214306  179.500000  0.029854
# 2021-04-12  183.667089  176.490005  0.029854
# 2021-04-13  183.149971  177.949997  0.029854
# 2021-04-14  182.661298  176.429993  0.029854
# 2021-04-15  182.199505  175.350006  0.029854
# 2021-04-16  181.763113  178.690002  0.029854
# 2021-04-19  181.350725  174.580002  0.029854
# 2021-04-20  180.961022  169.570007  0.029854
# 2021-04-21  180.592754  167.070007  0.029854
# 2021-04-22  180.244743  170.710007  0.029854
# 2021-04-23  179.915875  174.250000  0.029854
# 2021-04-26  179.605096  174.880005  0.029854
# 2021-04-27  179.311412  177.940002  0.029854
# 2021-04-28  179.033883  180.000000  0.029854
# 2021-04-29  178.771619  177.679993  0.029854
# 2021-04-30  178.523782  172.710007  0.029854

# %%
#calculate MPE score

arma_mpe = np.mean(arma_df['MPE'])

arma_mpe
# Out:
# 0.02985394063658454

# %%
plt.figure(figsize=(16,8))
plt.plot(y_train,label='Train')
plt.plot(y_test,label='Actual')
plt.plot(y_arma,label='ARIMA Predict')
plt.ylabel("Stock prices")
plt.title('MRNA ARMA Model',fontsize=20)
#save fig
plt.savefig("ARMA_MRNA.png",)

plt.show()

# %% [markdown]
# ### Visualize results

# %%
mse_df = pd.DataFrame({'Ticker':['ABNB', 'ABNB'],
                       'Model':['ARIMA', 'ARMA'],
                    'MSE Score':[arima_mse, arma_mse,],   
                    'MPE Score':[arima_mpe, arma_mpe]})
                   
mse_df
# Out:
#   Ticker  Model   MSE Score  MPE Score
# 0   ABNB  ARIMA  291.075292   0.089603
# 1   ABNB   ARMA   42.344096   0.029854

# %%
#export MSE table

mse_df.to_csv('ABNB_MSE.csv')
