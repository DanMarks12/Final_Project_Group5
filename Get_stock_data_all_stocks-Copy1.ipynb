# %%
#you may have to do this to start
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (0.9.0)
# Requirement already satisfied: lxml in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from pandas-datareader) (4.6.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from pandas-datareader) (2.25.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from pandas-datareader) (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.23->pandas-datareader) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.19.0->pandas-datareader) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\perry\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2020.6.20)

# %%
# import librarys
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from tqdm import tqdm_notebook as tqdm
import tensorflow

# %%
#read in ESG data
tech_comms_df = pd.read_csv('Tech and Comms Sustainability Scores 2.csv', index_col=0)
tech_comms_df
# Out:
#                                 Ticker  Sustainalytics Score  \
# Name
# Apple Inc.                        AAPL                  16.9
# Microsoft Corporation             MSFT                  14.6
# Visa Inc. Class A                    V                  17.4
# NVIDIA Corporation                NVDA                  13.3
# Mastercard Incorporated Class A     MA                  16.3
# ...                                ...                   ...
# T-Mobile US                       TMUS                  26.7
# Take-Two Interacti                TTWO                  17.3
# Twitter Inc                       TWTR                  24.9
# Viacom CBS Cl B                   VIAC                  16.1
# Verizon Communications Inc          VZ                  18.1
#
#                                                  Sector MSCI ESG 2017  \
# Name
# Apple Inc.                                         Tech             A
# Microsoft Corporation                              Tech           AAA
# Visa Inc. Class A                                  Tech             A
# NVIDIA Corporation                                 Tech            AA
# Mastercard Incorporated Class A                    Tech           BBB
# ...                                                 ...           ...
# T-Mobile US                      Communication Services            BB
# Take-Two Interacti               Communication Services           BBB
# Twitter Inc                      Communication Services             B
# Viacom CBS Cl B                  Communication Services             B
# Verizon Communications Inc       Communication Services            BB
#
#                                 MSCI ESG 2018 MSCI ESG 2019 MSCI ESG 2020  \
# Name
# Apple Inc.                                  A             A           BBB
# Microsoft Corporation                     AAA           AAA           AAA
# Visa Inc. Class A                           A             A             A
# NVIDIA Corporation                        AAA           AAA           AAA
# Mastercard Incorporated Class A           BBB             A             A
# ...                                       ...           ...           ...
# T-Mobile US                                 B             B            BB
# Take-Two Interacti                        BBB           BBB           BBB
# Twitter Inc                                 B            BB            BB
# Viacom CBS Cl B                             B             B            BB
# Verizon Communications Inc                BBB            BB           BBB
#
#                                 MSCI ESG 2021
# Name
# Apple Inc.                                BBB
# Microsoft Corporation                     AAA
# Visa Inc. Class A                           A
# NVIDIA Corporation                        AAA
# Mastercard Incorporated Class A             A
# ...                                       ...
# T-Mobile US                                BB
# Take-Two Interacti                        BBB
# Twitter Inc                                BB
# Viacom CBS Cl B                           BBB
# Verizon Communications Inc                BBB
#
# [98 rows x 8 columns]

# %%
#Import list of tickers
tickers_df = pd.read_csv('Tech and Comms Sustainability Scores.csv', index_col=0)
tickers_df
# Out:
#                                 Ticker  Sustainalytics Score  \
# Name
# Apple Inc.                        AAPL                  16.9
# Microsoft Corporation             MSFT                  14.6
# Visa Inc. Class A                    V                  17.4
# NVIDIA Corporation                NVDA                  13.3
# Mastercard Incorporated Class A     MA                  16.3
# ...                                ...                   ...
# T-Mobile US                       TMUS                  26.7
# Take-Two Interacti                TTWO                  17.3
# Twitter Inc                       TWTR                  24.9
# Viacom CBS Cl B                   VIAC                  16.1
# Verizon Communications Inc          VZ                  18.1
#
#                                                  Sector
# Name
# Apple Inc.                                         Tech
# Microsoft Corporation                              Tech
# Visa Inc. Class A                                  Tech
# NVIDIA Corporation                                 Tech
# Mastercard Incorporated Class A                    Tech
# ...                                                 ...
# T-Mobile US                      Communication Services
# Take-Two Interacti               Communication Services
# Twitter Inc                      Communication Services
# Viacom CBS Cl B                  Communication Services
# Verizon Communications Inc       Communication Services
#
# [98 rows x 3 columns]

# %% [markdown]
# ## 2019~2021 df

# %%
#for loop that pulls data for ticker from Yahoo finance and adds to new df
tickers_list = tickers_df['Ticker'].tolist()
full_df = pd.DataFrame()
for item in tqdm(tickers_list):
    try:
        temp_df = web.DataReader(item, data_source='yahoo', start='2019-01-01', end='2021-04-28')
        temp_df.columns = [item + '_' + e for e in temp_df.columns.tolist()]
        full_df = pd.concat([full_df, temp_df], axis=1)
    except:
        continue
# Out:
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))

# %%
full_df
# Out:
#              AAPL_High    AAPL_Low   AAPL_Open  AAPL_Close  AAPL_Volume  \
# Date
# 2019-01-02   39.712502   38.557499   38.722500   39.480000  148158800.0
# 2019-01-03   36.430000   35.500000   35.994999   35.547501  365248800.0
# 2019-01-04   37.137501   35.950001   36.132500   37.064999  234428400.0
# 2019-01-07   37.207500   36.474998   37.174999   36.982498  219111200.0
# 2019-01-08   37.955002   37.130001   37.389999   37.687500  164101200.0
# ...                ...         ...         ...         ...          ...
# 2021-04-22  134.149994  131.410004  133.039993  131.940002   84566500.0
# 2021-04-23  135.119995  132.160004  132.160004  134.320007   78657500.0
# 2021-04-26  135.059998  133.559998  134.830002  134.720001   66905100.0
# 2021-04-27  135.410004  134.110001  135.009995  134.389999   66015800.0
# 2021-04-28  135.020004  133.080002  134.309998  133.580002  107760100.0
#
#             AAPL_Adj Close   MSFT_High    MSFT_Low   MSFT_Open  MSFT_Close  \
# Date
# 2019-01-02       38.439735  101.750000   98.940002   99.550003  101.120003
# 2019-01-03       34.610851  100.190002   97.199997  100.099998   97.400002
# 2019-01-04       36.088364  102.510002   98.930000   99.720001  101.930000
# 2019-01-07       36.008041  103.269997  100.980003  101.639999  102.059998
# 2019-01-08       36.694466  103.970001  101.709999  103.040001  102.800003
# ...                    ...         ...         ...         ...         ...
# 2021-04-22      131.716278  261.779999  255.639999  260.209991  257.170013
# 2021-04-23      134.092239  261.510010  257.269989  257.880005  261.149994
# 2021-04-26      134.491562  262.440002  260.170013  261.660004  261.549988
# 2021-04-27      134.162109  263.190002  260.119995  261.579987  261.970001
# 2021-04-28      133.353485  256.540009  252.949997  256.079987  254.559998
#
#             ...  VIAC_Open  VIAC_Close  VIAC_Volume  VIAC_Adj Close  \
# Date        ...
# 2019-01-02  ...  43.619999   45.660000    4704600.0       43.237495
# 2019-01-03  ...  45.330002   46.130001    5106600.0       43.682560
# 2019-01-04  ...  46.599998   47.169998    3917700.0       44.667377
# 2019-01-07  ...  47.130001   47.669998    3413800.0       45.140850
# 2019-01-08  ...  48.009998   48.369999    3219900.0       45.803715
# ...         ...        ...         ...          ...             ...
# 2021-04-22  ...  42.250000   40.730000   60658800.0       40.730000
# 2021-04-23  ...  40.869999   41.709999   40878500.0       41.709999
# 2021-04-26  ...  42.439999   41.820000   30501300.0       41.820000
# 2021-04-27  ...  41.990002   42.810001   33759800.0       42.810001
# 2021-04-28  ...  42.860001   41.430000   27913200.0       41.430000
#
#               VZ_High     VZ_Low    VZ_Open   VZ_Close   VZ_Volume  \
# Date
# 2019-01-02  56.160000  55.279999  56.160000  56.020000  13969700.0
# 2019-01-03  56.990002  56.060001  56.299999  56.220001  19245400.0
# 2019-01-04  56.889999  55.950001  56.490002  56.360001  17035800.0
# 2019-01-07  57.259998  56.549999  56.759998  56.720001  16349000.0
# 2019-01-08  58.689999  57.049999  57.270000  58.380001  21424600.0
# ...               ...        ...        ...        ...         ...
# 2021-04-22  58.090000  57.139999  57.939999  57.279999  20921900.0
# 2021-04-23  57.470001  56.779999  57.130001  57.299999  18099400.0
# 2021-04-26  57.389999  56.849998  57.360001  56.939999  15073600.0
# 2021-04-27  56.720001  56.200001  56.580002  56.320000  21858600.0
# 2021-04-28  56.660000  56.340000  56.369999  56.430000  12862500.0
#
#             VZ_Adj Close
# Date
# 2019-01-02     50.405243
# 2019-01-03     50.585201
# 2019-01-04     50.711178
# 2019-01-07     51.035088
# 2019-01-08     52.528713
# ...                  ...
# 2021-04-22     57.279999
# 2021-04-23     57.299999
# 2021-04-26     56.939999
# 2021-04-27     56.320000
# 2021-04-28     56.430000
#
# [585 rows x 564 columns]

# %%
full_df.to_csv('full_df.csv')

# %%
#drop everything but close columns, then divide price on April 28, 2021 by price on January 1, 2019 to get percent return for each stock

cols_to_keep = [e for e in full_df.columns.tolist() if 'Close' in e]
first = full_df[cols_to_keep].iloc[0,:]
last = full_df[cols_to_keep].iloc[584,:]
return_19_21_df = pd.DataFrame(last/first, columns = ['return']) 
return_19_21_df.index = [e.replace('_Close', '') for e in return_19_21_df.index.tolist()]
return_19_21_df.reset_index(inplace=True)
return_19_21_df
# Out:
#    index    return
# 0   AAPL  3.383485
# 1   MSFT  2.517405
# 2      V  1.756320
# 3   NVDA  4.485905
# 4     MA  2.085222
# ..   ...       ...
# 89  TMUS  2.023904
# 90  TTWO  1.676570
# 91  TWTR  2.280458
# 92  VIAC  0.907359
# 93    VZ  1.007319
#
# [94 rows x 2 columns]

# %%
#merge data frame so returns during time period shown for each stock
tech_comms_df_final = tech_comms_df.merge(return_19_21_df, left_on='Ticker', right_on='index')
tech_comms_df_final
# Out:
#    Ticker  Sustainalytics Score                  Sector MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech             A
# 1    MSFT                  14.6                    Tech           AAA
# 2       V                  17.4                    Tech             A
# 3    NVDA                  13.3                    Tech            AA
# 4      MA                  16.3                    Tech           BBB
# ..    ...                   ...                     ...           ...
# 89   TMUS                  26.7  Communication Services            BB
# 90   TTWO                  17.3  Communication Services           BBB
# 91   TWTR                  24.9  Communication Services             B
# 92   VIAC                  16.1  Communication Services             B
# 93     VZ                  18.1  Communication Services            BB
#
#    MSCI ESG 2018 MSCI ESG 2019 MSCI ESG 2020 MSCI ESG 2021 index    return
# 0              A             A           BBB           BBB  AAPL  3.383485
# 1            AAA           AAA           AAA           AAA  MSFT  2.517405
# 2              A             A             A             A     V  1.756320
# 3            AAA           AAA           AAA           AAA  NVDA  4.485905
# 4            BBB             A             A             A    MA  2.085222
# ..           ...           ...           ...           ...   ...       ...
# 89             B             B            BB            BB  TMUS  2.023904
# 90           BBB           BBB           BBB           BBB  TTWO  1.676570
# 91             B            BB            BB            BB  TWTR  2.280458
# 92             B             B            BB           BBB  VIAC  0.907359
# 93           BBB            BB           BBB           BBB    VZ  1.007319
#
# [94 rows x 10 columns]

# %%
#code the MSCI ESG scores to be numerical instead of categorical
dict  = {'CCC':0, 'B':1, 'BB':2, 'BBB':3, 'A':4, 'AA':5, 'AAA':6}
years = ['MSCI ESG 2017', 'MSCI ESG 2018', 'MSCI ESG 2019', 'MSCI ESG 2020', 'MSCI ESG 2021']
for y in years:
    tech_comms_df_final[y] = tech_comms_df_final[y].map(dict)
tech_comms_df_final
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 89   TMUS                  26.7  Communication Services            2.0
# 90   TTWO                  17.3  Communication Services            3.0
# 91   TWTR                  24.9  Communication Services            1.0
# 92   VIAC                  16.1  Communication Services            1.0
# 93     VZ                  18.1  Communication Services            2.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index    return
# 0             4.0            4.0            3.0            3.0  AAPL  3.383485
# 1             6.0            6.0            6.0            6.0  MSFT  2.517405
# 2             4.0            4.0            4.0            4.0     V  1.756320
# 3             6.0            6.0            6.0            6.0  NVDA  4.485905
# 4             3.0            4.0            4.0            4.0    MA  2.085222
# ..            ...            ...            ...            ...   ...       ...
# 89            1.0            1.0            2.0            2.0  TMUS  2.023904
# 90            3.0            3.0            3.0            3.0  TTWO  1.676570
# 91            1.0            2.0            2.0            2.0  TWTR  2.280458
# 92            1.0            1.0            2.0            3.0  VIAC  0.907359
# 93            3.0            2.0            3.0            3.0    VZ  1.007319
#
# [94 rows x 10 columns]

# %% [markdown]
# ## 2017 df

# %%
#create for loop to pull stock data for 2017 and add as column
from tqdm import tqdm_notebook as tqdm
full_2017_df = pd.DataFrame()
for item in tqdm(tickers_list):
    try:
        temp_df = web.DataReader(item, data_source='yahoo', start='2017-01-01', end='2017-12-31')
        temp_df.columns = [item + '_' + e for e in temp_df.columns.tolist()]
        full_2017_df = pd.concat([full_2017_df, temp_df], axis=1)
    except:
        continue
# Out:
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')
# 2017-01-04  54.330002  54.549999  54.520000  18316100.0     44.662155
# 2017-01-05  54.299999  54.779999  54.639999  13840600.0     44.760460
# 2017-01-06  53.099998  53.669998  53.259998  15615000.0     44.096455
# 2017-01-09  52.669998  53.220001  52.680000  14097200.0     43.616238
# ...               ...        ...        ...         ...           ...
# 2017-12-22  53.060001  53.110001  53.189999  13657800.0     45.690029
# 2017-12-26  53.130001  53.130001  53.220001   6595800.0     45.715801
# 2017-12-27  53.090000  53.410000  53.279999   8361900.0     45.767342
# 2017-12-28  53.160000  53.410000  53.430000   6726300.0     45.896187
# 2017-12-29  52.930000  53.369999  52.930000   9994700.0     45.466686
#
# [251 rows x 528 columns]

# %%
full_2017_df.to_csv('full_2017_df.csv')

# %%
#create DF of just tickers and 2017 returns
cols_to_keep = [e for e in full_2017_df.columns.tolist() if '_Close' in e]
first17 = full_2017_df[cols_to_keep].iloc[0,:]
last17 = full_2017_df[cols_to_keep].iloc[-1,:]
return_2017_df = pd.DataFrame(last17/first17, columns = ['return']) 
return_2017_df.index = [e.replace('_Close', '') for e in return_2017_df.index.tolist()]
return_2017_df.reset_index(inplace=True)
return_2017_df
# Out:
#    index    return
# 0   AAPL  1.456995
# 1   MSFT  1.366890
# 2      V  1.434214
# 3   NVDA  1.896873
# 4     MA  1.436189
# ..   ...       ...
# 83     T  0.903766
# 84  TTWO  2.230394
# 85  TWTR  1.460462
# 86  VIAC  0.916291
# 87    VZ  0.969769
#
# [88 rows x 2 columns]

# %%
#merge 2017 returns to overall DF
returns_2017_final_df = tech_comms_df_final.merge(return_2017_df, left_on='Ticker', right_on='index')
returns_2017_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 81      T                  19.1  Communication Services            2.0
# 82   TTWO                  17.3  Communication Services            3.0
# 83   TWTR                  24.9  Communication Services            1.0
# 84   VIAC                  16.1  Communication Services            1.0
# 85     VZ                  18.1  Communication Services            2.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 81            3.0            2.0            2.0            2.0       T
# 82            3.0            3.0            3.0            3.0    TTWO
# 83            1.0            2.0            2.0            2.0    TWTR
# 84            1.0            1.0            2.0            3.0    VIAC
# 85            3.0            2.0            3.0            3.0      VZ
#
#     return_x index_y  return_y
# 0   3.383485    AAPL  1.456995
# 1   2.517405    MSFT  1.366890
# 2   1.756320       V  1.434214
# 3   4.485905    NVDA  1.896873
# 4   2.085222      MA  1.436189
# ..       ...     ...       ...
# 81  1.048070       T  0.903766
# 82  1.676570    TTWO  2.230394
# 83  2.280458    TWTR  1.460462
# 84  0.907359    VIAC  0.916291
# 85  1.007319      VZ  0.969769
#
# [86 rows x 12 columns]

# %%
#rename new column
returns_2017_final_df.rename(columns={"return_x" : "2019-2021 Returns", "return_y": "2017 Returns"}, inplace = True)
returns_2017_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 81      T                  19.1  Communication Services            2.0
# 82   TTWO                  17.3  Communication Services            3.0
# 83   TWTR                  24.9  Communication Services            1.0
# 84   VIAC                  16.1  Communication Services            1.0
# 85     VZ                  18.1  Communication Services            2.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 81            3.0            2.0            2.0            2.0       T
# 82            3.0            3.0            3.0            3.0    TTWO
# 83            1.0            2.0            2.0            2.0    TWTR
# 84            1.0            1.0            2.0            3.0    VIAC
# 85            3.0            2.0            3.0            3.0      VZ
#
#     2019-2021 Returns index_y  2017 Returns
# 0            3.383485    AAPL      1.456995
# 1            2.517405    MSFT      1.366890
# 2            1.756320       V      1.434214
# 3            4.485905    NVDA      1.896873
# 4            2.085222      MA      1.436189
# ..                ...     ...           ...
# 81           1.048070       T      0.903766
# 82           1.676570    TTWO      2.230394
# 83           2.280458    TWTR      1.460462
# 84           0.907359    VIAC      0.916291
# 85           1.007319      VZ      0.969769
#
# [86 rows x 12 columns]

# %% [markdown]
# ## 2018 df

# %%
#create for loop to pull stock data for 2018 and add as column
from tqdm import tqdm_notebook as tqdm
full_2018_df = pd.DataFrame()
for item in tqdm(tickers_list):
    try:
        temp_df = web.DataReader(item, data_source='yahoo', start='2018-01-01', end='2018-12-31')
        temp_df.columns = [item + '_' + e for e in temp_df.columns.tolist()]
        full_2018_df = pd.concat([full_2018_df, temp_df], axis=1)
    except:
        continue
# Out:
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))

# %%
full_2018_df
# Out:
#             AAPL_High   AAPL_Low  AAPL_Open  AAPL_Close  AAPL_Volume  \
# Date
# 2018-01-02  43.075001  42.314999  42.540001   43.064999  102223600.0
# 2018-01-03  43.637501  42.990002  43.132500   43.057499  118071600.0
# 2018-01-04  43.367500  43.020000  43.134998   43.257500   89738400.0
# 2018-01-05  43.842499  43.262501  43.360001   43.750000   94640000.0
# 2018-01-08  43.902500  43.482498  43.587502   43.587502   82271200.0
# ...               ...        ...        ...         ...          ...
# 2018-12-24  37.887501  36.647499  37.037498   36.707500  148676800.0
# 2018-12-26  39.307499  36.680000  37.075001   39.292500  234330000.0
#create DF of just tickers and 2018 returns
cols_to_keep = [e for e in full_2018_df.columns.tolist() if '_Close' in e]
first18 = full_2018_df[cols_to_keep].iloc[0,:]
last18 = full_2018_df[cols_to_keep].iloc[-1,:]
return_2018_df = pd.DataFrame(last18/first18, columns = ['return']) 
return_2018_df.index = [e.replace('_Close', '') for e in return_2018_df.index.tolist()]
return_2018_df.reset_index(inplace=True)
return_2018_df
# Out:
#    index    return
# 0   AAPL  0.915709
# 1   MSFT  1.181734
# 2      V  1.152214
# 3   NVDA  0.669676
# 4     MA  1.241854
# ..   ...       ...
# 82  TMUS  0.993285
# 83  TTWO  0.911942
# 84  TWTR  1.172583
# 85  VIAC  0.738888
# 86    VZ  1.050252
#
# [87 rows x 2 columns]

# %%
#merge 2018 returns to overall DF
returns_2018_final_df = returns_2017_final_df.merge(return_2018_df, left_on='Ticker', right_on='index')
returns_2018_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 71      T                  19.1  Communication Services            2.0
# 72   TTWO                  17.3  Communication Services            3.0
# 73   TWTR                  24.9  Communication Services            1.0
# 74   VIAC                  16.1  Communication Services            1.0
# 75     VZ                  18.1  Communication Services            2.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 71            3.0            2.0            2.0            2.0       T
# 72            3.0            3.0            3.0            3.0    TTWO
# 73            1.0            2.0            2.0            2.0    TWTR
# 74            1.0            1.0            2.0            3.0    VIAC
# 75            3.0            2.0            3.0            3.0      VZ
#
#     2019-2021 Returns index_y  2017 Returns index    return
# 0            3.383485    AAPL      1.456995  AAPL  0.915709
# 1            2.517405    MSFT      1.366890  MSFT  1.181734
# 2            1.756320       V      1.434214     V  1.152214
# 3            4.485905    NVDA      1.896873  NVDA  0.669676
# 4            2.085222      MA      1.436189    MA  1.241854
# ..                ...     ...           ...   ...       ...
# 71           1.048070       T      0.903766     T  0.740529
# 72           1.676570    TTWO      2.230394  TTWO  0.911942
# 73           2.280458    TWTR      1.460462  TWTR  1.172583
# 74           0.907359    VIAC      0.916291  VIAC  0.738888
# 75           1.007319      VZ      0.969769    VZ  1.050252
#
# [76 rows x 14 columns]

# %%
#rename new column
returns_2018_final_df.rename(columns={"return" : "2018 Returns"}, inplace = True)
returns_2018_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 71      T                  19.1  Communication Services            2.0
# 72   TTWO                  17.3  Communication Services            3.0
# 73   TWTR                  24.9  Communication Services            1.0
# 74   VIAC                  16.1  Communication Services            1.0
# 75     VZ                  18.1  Communication Services            2.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 71            3.0            2.0            2.0            2.0       T
# 72            3.0            3.0            3.0            3.0    TTWO
# 73            1.0            2.0            2.0            2.0    TWTR
# 74            1.0            1.0            2.0            3.0    VIAC
# 75            3.0            2.0            3.0            3.0      VZ
#
#     2019-2021 Returns index_y  2017 Returns index  2018 Returns
# 0            3.383485    AAPL      1.456995  AAPL      0.915709
# 1            2.517405    MSFT      1.366890  MSFT      1.181734
# 2            1.756320       V      1.434214     V      1.152214
# 3            4.485905    NVDA      1.896873  NVDA      0.669676
# 4            2.085222      MA      1.436189    MA      1.241854
# ..                ...     ...           ...   ...           ...
# 71           1.048070       T      0.903766     T      0.740529
# 72           1.676570    TTWO      2.230394  TTWO      0.911942
# 73           2.280458    TWTR      1.460462  TWTR      1.172583
# 74           0.907359    VIAC      0.916291  VIAC      0.738888
# 75           1.007319      VZ      0.969769    VZ      1.050252
#
# [76 rows x 14 columns]

# %% [markdown]
# ## 2019 df

# %%
#create for loop to pull stock data for 2019 and add as column
from tqdm import tqdm_notebook as tqdm
full_2019_df = pd.DataFrame()
for item in tqdm(tickers_list):
    try:
        temp_df = web.DataReader(item, data_source='yahoo', start='2019-01-01', end='2019-12-31')
        temp_df.columns = [item + '_' + e for e in temp_df.columns.tolist()]
        full_2019_df = pd.concat([full_2019_df, temp_df], axis=1)
    except:
        continue
# Out:
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))

# %%
full_2019_df
# Out:
#             AAPL_High   AAPL_Low  AAPL_Open  AAPL_Close  AAPL_Volume  \
# Date
# 2019-01-02  39.712502  38.557499  38.722500   39.480000  148158800.0
# 2019-01-03  36.430000  35.500000  35.994999   35.547501  365248800.0
# 2019-01-04  37.137501  35.950001  36.132500   37.064999  234428400.0
# 2019-01-07  37.207500  36.474998  37.174999   36.982498  219111200.0
# 2019-01-08  37.955002  37.130001  37.389999   37.687500  164101200.0
# ...               ...        ...        ...         ...          ...
# 2019-12-24  71.222504  70.730003  71.172501   71.067497   48478800.0
# 2019-12-26  72.495003  71.175003  71.205002   72.477501   93121200.0
# 2019-12-27  73.492500  72.029999  72.779999   72.449997  146266000.0
# 2019-12-30  73.172501  71.305000  72.364998   72.879997  144114400.0
# 2019-12-31  73.419998  72.379997  72.482498   73.412498  100805600.0
#
#             AAPL_Adj Close   MSFT_High    MSFT_Low   MSFT_Open  MSFT_Close  \
# Date
# 2019-01-02       38.439735  101.750000   98.940002   99.550003  101.120003
# 2019-01-03       34.610851  100.190002   97.199997  100.099998   97.400002
# 2019-01-04       36.088364  102.510002   98.930000   99.720001  101.930000
# 2019-01-07       36.008041  103.269997  100.980003  101.639999  102.059998
# 2019-01-08       36.694466  103.970001  101.709999  103.040001  102.800003
# ...                    ...         ...         ...         ...         ...
# 2019-12-24       70.234581  157.710007  157.119995  157.479996  157.380005
# 2019-12-26       71.628067  158.729996  157.399994  157.559998  158.669998
# 2019-12-27       71.600876  159.550003  158.220001  159.449997  158.960007
# 2019-12-30       72.025833  159.020004  156.729996  158.990005  157.589996
# 2019-12-31       72.552094  157.770004  156.449997  156.770004  157.699997
#
#             ...  VIAC_Open  VIAC_Close  VIAC_Volume  VIAC_Adj Close  \
# Date        ...
# 2019-01-02  ...  43.619999   45.660000    4704600.0       43.237495
# 2019-01-03  ...  45.330002   46.130001    5106600.0       43.682560
# 2019-01-04  ...  46.599998   47.169998    3917700.0       44.667377
# 2019-01-07  ...  47.130001   47.669998    3413800.0       45.140850
# 2019-01-08  ...  48.009998   48.369999    3219900.0       45.803715
# ...         ...        ...         ...          ...             ...
# 2019-12-24  ...  42.180000   42.020000    2824200.0       40.251926
# 2019-12-26  ...  42.209999   42.660000    3522000.0       40.864998
# 2019-12-27  ...  42.549999   41.759998    4175900.0       40.002869
# 2019-12-30  ...  41.779999   41.480000    4462000.0       39.734646
# 2019-12-31  ...  41.470001   41.970001    3993000.0       40.204029
#
#               VZ_High     VZ_Low    VZ_Open   VZ_Close   VZ_Volume  \
# Date
# 2019-01-02  56.160000  55.279999  56.160000  56.020000  13969700.0
# 2019-01-03  56.990002  56.060001  56.299999  56.220001  19245400.0
# 2019-01-04  56.889999  55.950001  56.490002  56.360001  17035800.0
# 2019-01-07  57.259998  56.549999  56.759998  56.720001  16349000.0
# 2019-01-08  58.689999  57.049999  57.270000  58.380001  21424600.0
# ...               ...        ...        ...        ...         ...
# 2019-12-24  61.459999  61.020000  61.459999  61.279999   6640100.0
# 2019-12-26  61.369999  61.110001  61.279999  61.290001   8117800.0
# 2019-12-27  61.619999  61.250000  61.389999  61.529999   8166800.0
# 2019-12-30  61.689999  61.090000  61.650002  61.209999   6765400.0
# 2019-12-31  61.400002  60.939999  61.209999  61.400002   8466700.0
#
#             VZ_Adj Close
# Date
# 2019-01-02     50.405243
# 2019-01-03     50.585201
# 2019-01-04     50.711178
# 2019-01-07     51.035088
# 2019-01-08     52.528713
# ...                  ...
# 2019-12-24     57.471848
# 2019-12-26     57.481236
# 2019-12-27     57.706314
# 2019-12-30     57.406197
# 2019-12-31     57.584396
#
# [252 rows x 552 columns]

# %%
full_2019_df.to_csv('full_2019_df.csv')

# %%
#create DF of just tickers and 2019 returns
cols_to_keep = [e for e in full_2019_df.columns.tolist() if '_Close' in e]
first19 = full_2019_df[cols_to_keep].iloc[0,:]
last19 = full_2019_df[cols_to_keep].iloc[-1,:]
return_2019_df = pd.DataFrame(last19/first19, columns = ['return']) 
return_2019_df.index = [e.replace('_Close', '') for e in return_2019_df.index.tolist()]
return_2019_df.reset_index(inplace=True)
return_2019_df
# Out:
#    index    return
# 0   AAPL  1.859486
# 1   MSFT  1.559533
# 2      V  1.413632
# 3   NVDA  1.727353
# 4     MA  1.573680
# ..   ...       ...
# 87     T  1.322952
# 88  TMUS  1.201655
# 89  TTWO  1.177098
# 90  VIAC  0.919185
# 91    VZ  1.096037
#
# [92 rows x 2 columns]

# %%
#merge 2019 returns to overall DF
returns_2019_final_df = returns_2018_final_df.merge(return_2019_df, left_on='Ticker', right_on='index')
returns_2019_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 68   NWSA                  13.4  Communication Services            0.0
# 69      T                  19.1  Communication Services            2.0
# 70   TTWO                  17.3  Communication Services            3.0
# 71   VIAC                  16.1  Communication Services            1.0
# 72     VZ                  18.1  Communication Services            2.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 68            0.0            0.0            0.0            0.0    NWSA
# 69            3.0            2.0            2.0            2.0       T
# 70            3.0            3.0            3.0            3.0    TTWO
# 71            1.0            1.0            2.0            3.0    VIAC
# 72            3.0            2.0            3.0            3.0      VZ
#
#     2019-2021 Returns index_y  2017 Returns index_x  2018 Returns index_y  \
# 0            3.383485    AAPL      1.456995    AAPL      0.915709    AAPL
# 1            2.517405    MSFT      1.366890    MSFT      1.181734    MSFT
# 2            1.756320       V      1.434214       V      1.152214       V
# 3            4.485905    NVDA      1.896873    NVDA      0.669676    NVDA
# 4            2.085222      MA      1.436189      MA      1.241854      MA
# ..                ...     ...           ...     ...           ...     ...
# 68           2.297629    NWSA      1.386655    NWSA      0.690810    NWSA
# 69           1.048070       T      0.903766       T      0.740529       T
# 70           1.676570    TTWO      2.230394    TTWO      0.911942    TTWO
# 71           0.907359    VIAC      0.916291    VIAC      0.738888    VIAC
# 72           1.007319      VZ      0.969769      VZ      1.050252      VZ
#
#       return
# 0   1.859486
# 1   1.559533
# 2   1.413632
# 3   1.727353
# 4   1.573680
# ..       ...
# 68  1.241440
# 69  1.322952
# 70  1.177098
# 71  0.919185
# 72  1.096037
#
# [73 rows x 16 columns]

# %%
#rename new column
returns_2019_final_df.rename(columns={"return" : "2019 Returns"}, inplace = True)
returns_2019_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 68   NWSA                  13.4  Communication Services            0.0
# 69      T                  19.1  Communication Services            2.0
# 70   TTWO                  17.3  Communication Services            3.0
# 71   VIAC                  16.1  Communication Services            1.0
# 72     VZ                  18.1  Communication Services            2.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 68            0.0            0.0            0.0            0.0    NWSA
# 69            3.0            2.0            2.0            2.0       T
# 70            3.0            3.0            3.0            3.0    TTWO
# 71            1.0            1.0            2.0            3.0    VIAC
# 72            3.0            2.0            3.0            3.0      VZ
#
#     2019-2021 Returns index_y  2017 Returns index_x  2018 Returns index_y  \
# 0            3.383485    AAPL      1.456995    AAPL      0.915709    AAPL
# 1            2.517405    MSFT      1.366890    MSFT      1.181734    MSFT
# 2            1.756320       V      1.434214       V      1.152214       V
# 3            4.485905    NVDA      1.896873    NVDA      0.669676    NVDA
# 4            2.085222      MA      1.436189      MA      1.241854      MA
# ..                ...     ...           ...     ...           ...     ...
# 68           2.297629    NWSA      1.386655    NWSA      0.690810    NWSA
# 69           1.048070       T      0.903766       T      0.740529       T
# 70           1.676570    TTWO      2.230394    TTWO      0.911942    TTWO
# 71           0.907359    VIAC      0.916291    VIAC      0.738888    VIAC
# 72           1.007319      VZ      0.969769      VZ      1.050252      VZ
#
#     2019 Returns
# 0       1.859486
# 1       1.559533
# 2       1.413632
# 3       1.727353
# 4       1.573680
# ..           ...
# 68      1.241440
# 69      1.322952
# 70      1.177098
# 71      0.919185
# 72      1.096037
#
# [73 rows x 16 columns]

# %% [markdown]
# ## 2020 df

# %%
#create for loop to pull stock data for 2020 and add as column
from tqdm import tqdm_notebook as tqdm
full_2020_df = pd.DataFrame()
for item in tqdm(tickers_list):
    try:
        temp_df = web.DataReader(item, data_source='yahoo', start='2020-01-01', end='2020-12-31')
        temp_df.columns = [item + '_' + e for e in temp_df.columns.tolist()]
        full_2020_df = pd.concat([full_2020_df, temp_df], axis=1)
    except:
        continue
# Out:
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))

# %%
full_2020_df
# Out:
#              AAPL_High    AAPL_Low   AAPL_Open  AAPL_Close  AAPL_Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2020-12-24  133.460007  131.100006  131.320007  131.970001   54930100.0
# 2020-12-28  137.339996  133.509995  133.990005  136.690002  124486200.0
# 2020-12-29  138.789993  134.339996  138.050003  134.869995  121047300.0
# 2020-12-30  135.990005  133.399994  135.580002  133.720001   96452100.0
first20 = full_2020_df[cols_to_keep].iloc[0,:]
last20 = full_2020_df[cols_to_keep].iloc[-1,:]
return_2020_df = pd.DataFrame(last20/first20, columns = ['return']) 
return_2020_df.index = [e.replace('_Close', '') for e in return_2020_df.index.tolist()]
return_2020_df.reset_index(inplace=True)
return_2020_df
# Out:
#    index    return
# 0   AAPL  1.767138
# 1   MSFT  1.384759
# 2      V  1.144464
# 3   NVDA  2.176650
# 4     MA  1.176505
# ..   ...       ...
# 84     T  0.740093
# 85  TMUS  1.715867
# 86  TTWO  1.702081
# 87  VIAC  0.885246
# 88    VZ  0.962326
#
# [89 rows x 2 columns]

# %%
#merge 2020 returns to overall DF
returns_2020_final_df = returns_2019_final_df.merge(return_2020_df, left_on='Ticker', right_on='index')
returns_2020_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 62   NWSA                  13.4  Communication Services            0.0
# 63      T                  19.1  Communication Services            2.0
# 64   TTWO                  17.3  Communication Services            3.0
# 65   VIAC                  16.1  Communication Services            1.0
# 66     VZ                  18.1  Communication Services            2.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 62            0.0            0.0            0.0            0.0    NWSA
# 63            3.0            2.0            2.0            2.0       T
# 64            3.0            3.0            3.0            3.0    TTWO
# 65            1.0            1.0            2.0            3.0    VIAC
# 66            3.0            2.0            3.0            3.0      VZ
#
#     2019-2021 Returns index_y  2017 Returns index_x  2018 Returns index_y  \
# 0            3.383485    AAPL      1.456995    AAPL      0.915709    AAPL
# 1            2.517405    MSFT      1.366890    MSFT      1.181734    MSFT
# 2            1.756320       V      1.434214       V      1.152214       V
# 3            4.485905    NVDA      1.896873    NVDA      0.669676    NVDA
# 4            2.085222      MA      1.436189      MA      1.241854      MA
# ..                ...     ...           ...     ...           ...     ...
# 62           2.297629    NWSA      1.386655    NWSA      0.690810    NWSA
# 63           1.048070       T      0.903766       T      0.740529       T
# 64           1.676570    TTWO      2.230394    TTWO      0.911942    TTWO
# 65           0.907359    VIAC      0.916291    VIAC      0.738888    VIAC
# 66           1.007319      VZ      0.969769      VZ      1.050252      VZ
#
#     2019 Returns index    return
# 0       1.859486  AAPL  1.767138
# 1       1.559533  MSFT  1.384759
# 2       1.413632     V  1.144464
# 3       1.727353  NVDA  2.176650
# 4       1.573680    MA  1.176505
# ..           ...   ...       ...
# 62      1.241440  NWSA  1.244460
# 63      1.322952     T  0.740093
# 64      1.177098  TTWO  1.702081
# 65      0.919185  VIAC  0.885246
# 66      1.096037    VZ  0.962326
#
# [67 rows x 18 columns]

# %%
#rename new column
returns_2020_final_df.rename(columns={"return" : "2020 Returns"}, inplace = True)
returns_2020_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 62   NWSA                  13.4  Communication Services            0.0
# 63      T                  19.1  Communication Services            2.0
# 64   TTWO                  17.3  Communication Services            3.0
# 65   VIAC                  16.1  Communication Services            1.0
# 66     VZ                  18.1  Communication Services            2.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 62            0.0            0.0            0.0            0.0    NWSA
# 63            3.0            2.0            2.0            2.0       T
# 64            3.0            3.0            3.0            3.0    TTWO
# 65            1.0            1.0            2.0            3.0    VIAC
# 66            3.0            2.0            3.0            3.0      VZ
#
#     2019-2021 Returns index_y  2017 Returns index_x  2018 Returns index_y  \
# 0            3.383485    AAPL      1.456995    AAPL      0.915709    AAPL
# 1            2.517405    MSFT      1.366890    MSFT      1.181734    MSFT
# 2            1.756320       V      1.434214       V      1.152214       V
# 3            4.485905    NVDA      1.896873    NVDA      0.669676    NVDA
# 4            2.085222      MA      1.436189      MA      1.241854      MA
# ..                ...     ...           ...     ...           ...     ...
# 62           2.297629    NWSA      1.386655    NWSA      0.690810    NWSA
# 63           1.048070       T      0.903766       T      0.740529       T
# 64           1.676570    TTWO      2.230394    TTWO      0.911942    TTWO
# 65           0.907359    VIAC      0.916291    VIAC      0.738888    VIAC
# 66           1.007319      VZ      0.969769      VZ      1.050252      VZ
#
#     2019 Returns index  2020 Returns
# 0       1.859486  AAPL      1.767138
# 1       1.559533  MSFT      1.384759
# 2       1.413632     V      1.144464
# 3       1.727353  NVDA      2.176650
# 4       1.573680    MA      1.176505
# ..           ...   ...           ...
# 62      1.241440  NWSA      1.244460
# 63      1.322952     T      0.740093
# 64      1.177098  TTWO      1.702081
# 65      0.919185  VIAC      0.885246
# 66      1.096037    VZ      0.962326
#
# [67 rows x 18 columns]

# %% [markdown]
# ## 2021 df

# %%
#create for loop to pull stock data for 2021 and add as column
from tqdm import tqdm_notebook as tqdm
full_2021_df = pd.DataFrame()
for item in tqdm(tickers_list):
    try:
        temp_df = web.DataReader(item, data_source='yahoo', start='2021-01-01', end='2021-04-28')
        temp_df.columns = [item + '_' + e for e in temp_df.columns.tolist()]
        full_2021_df = pd.concat([full_2021_df, temp_df], axis=1)
    except:
        continue
# Out:
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')
# 2021-04-28  42.959999  41.380001  42.860001   41.430000   27913200.0
#
#             VIAC_Adj Close
# Date
# 2021-01-04       36.498192
# 2021-01-05       36.887108
# 2021-01-06       40.088181
# 2021-01-07       40.008400
# 2021-01-08       39.948570
# ...                    ...
# 2021-04-22       40.730000
# 2021-04-23       41.709999
# 2021-04-26       41.820000
# 2021-04-27       42.810001
# 2021-04-28       41.430000
#
# [80 rows x 534 columns]

# %%
full_2021_df.to_csv('full_2021_df.csv')

# %%
#create DF of just tickers and 2021 returns
cols_to_keep = [e for e in full_2021_df.columns.tolist() if '_Close' in e]
first21 = full_2021_df[cols_to_keep].iloc[0,:]
last21 = full_2021_df[cols_to_keep].iloc[-1,:]
return_2021_df = pd.DataFrame(last21/first21, columns = ['return']) 
return_2021_df.index = [e.replace('_Close', '') for e in return_2021_df.index.tolist()]
return_2021_df.reset_index(inplace=True)
return_2021_df
# Out:
#    index    return
# 0   AAPL  1.032223
# 1   MSFT  1.169369
# 2      V  1.072052
# 3   NVDA  1.164964
# 4     MA  1.125637
# ..   ...       ...
# 84  NWSA  1.441079
# 85   OMC  1.336235
# 86  TMUS  0.997357
# 87  TTWO  0.863909
# 88  VIAC  1.131967
#
# [89 rows x 2 columns]

# %%
#merge 2021 returns to overall DF
returns_2021_final_df = returns_2020_final_df.merge(return_2021_df, left_on='Ticker', right_on='index')
returns_2021_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 57  GOOGL                  22.3  Communication Services            4.0
# 58   NFLX                  17.4  Communication Services            2.0
# 59   NWSA                  13.4  Communication Services            0.0
# 60   TTWO                  17.3  Communication Services            3.0
# 61   VIAC                  16.1  Communication Services            1.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 57            4.0            5.0            5.0            3.0   GOOGL
# 58            2.0            1.0            1.0            2.0    NFLX
# 59            0.0            0.0            0.0            0.0    NWSA
# 60            3.0            3.0            3.0            3.0    TTWO
# 61            1.0            1.0            2.0            3.0    VIAC
#
#     2019-2021 Returns index_y  2017 Returns index_x  2018 Returns index_y  \
# 0            3.383485    AAPL      1.456995    AAPL      0.915709    AAPL
# 1            2.517405    MSFT      1.366890    MSFT      1.181734    MSFT
# 2            1.756320       V      1.434214       V      1.152214       V
# 3            4.485905    NVDA      1.896873    NVDA      0.669676    NVDA
# 4            2.085222      MA      1.436189      MA      1.241854      MA
# ..                ...     ...           ...     ...           ...     ...
# 57           2.236735   GOOGL      1.303697   GOOGL      0.973677   GOOGL
# 58           1.892401    NFLX      1.505687    NFLX      1.331178    NFLX
# 59           2.297629    NWSA      1.386655    NWSA      0.690810    NWSA
# 60           1.676570    TTWO      2.230394    TTWO      0.911942    TTWO
# 61           0.907359    VIAC      0.916291    VIAC      0.738888    VIAC
#
#     2019 Returns index_x  2020 Returns index_y    return
# 0       1.859486    AAPL      1.767138    AAPL  1.032223
# 1       1.559533    MSFT      1.384759    MSFT  1.169369
# 2       1.413632       V      1.144464       V  1.072052
# 3       1.727353    NVDA      2.176650    NVDA  1.164964
# 4       1.573680      MA      1.176505      MA  1.125637
# ..           ...     ...           ...     ...       ...
# 57      1.269949   GOOGL      1.280533   GOOGL  1.366664
# 58      1.208884    NFLX      1.639520    NFLX  0.968749
# 59      1.241440    NWSA      1.244460    NWSA  1.441079
# 60      1.177098    TTWO      1.702081    TTWO  0.863909
# 61      0.919185    VIAC      0.885246    VIAC  1.131967
#
# [62 rows x 20 columns]

# %%
#rename new column
returns_2021_final_df.rename(columns={"return" : "2021 Returns"}, inplace = True)
returns_2021_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 57  GOOGL                  22.3  Communication Services            4.0
# 58   NFLX                  17.4  Communication Services            2.0
# 59   NWSA                  13.4  Communication Services            0.0
# 60   TTWO                  17.3  Communication Services            3.0
# 61   VIAC                  16.1  Communication Services            1.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 57            4.0            5.0            5.0            3.0   GOOGL
# 58            2.0            1.0            1.0            2.0    NFLX
# 59            0.0            0.0            0.0            0.0    NWSA
# 60            3.0            3.0            3.0            3.0    TTWO
# 61            1.0            1.0            2.0            3.0    VIAC
#
#     2019-2021 Returns index_y  2017 Returns index_x  2018 Returns index_y  \
# 0            3.383485    AAPL      1.456995    AAPL      0.915709    AAPL
# 1            2.517405    MSFT      1.366890    MSFT      1.181734    MSFT
# 2            1.756320       V      1.434214       V      1.152214       V
# 3            4.485905    NVDA      1.896873    NVDA      0.669676    NVDA
# 4            2.085222      MA      1.436189      MA      1.241854      MA
# ..                ...     ...           ...     ...           ...     ...
# 57           2.236735   GOOGL      1.303697   GOOGL      0.973677   GOOGL
# 58           1.892401    NFLX      1.505687    NFLX      1.331178    NFLX
# 59           2.297629    NWSA      1.386655    NWSA      0.690810    NWSA
# 60           1.676570    TTWO      2.230394    TTWO      0.911942    TTWO
# 61           0.907359    VIAC      0.916291    VIAC      0.738888    VIAC
#
#     2019 Returns index_x  2020 Returns index_y  2021 Returns
# 0       1.859486    AAPL      1.767138    AAPL      1.032223
# 1       1.559533    MSFT      1.384759    MSFT      1.169369
# 2       1.413632       V      1.144464       V      1.072052
# 3       1.727353    NVDA      2.176650    NVDA      1.164964
# 4       1.573680      MA      1.176505      MA      1.125637
# ..           ...     ...           ...     ...           ...
# 57      1.269949   GOOGL      1.280533   GOOGL      1.366664
# 58      1.208884    NFLX      1.639520    NFLX      0.968749
# 59      1.241440    NWSA      1.244460    NWSA      1.441079
# 60      1.177098    TTWO      1.702081    TTWO      0.863909
# 61      0.919185    VIAC      0.885246    VIAC      1.131967
#
# [62 rows x 20 columns]

# %%
returns_2021_final_df.to_csv('returns_2021_final_df.csv')

# %% [markdown]
# ## ESG and Return correlation by year

# %%
# find yearly correlation between MSCI ESG score and market returns 
corr_cols = [['MSCI ESG 2017', 'MSCI ESG 2018', 'MSCI ESG 2019', 'MSCI ESG 2020', 'MSCI ESG 2021'],
             ['2017 Returns', '2018 Returns', '2019 Returns', '2020 Returns', '2021 Returns']]
corr_cols = list(zip(*corr_cols))
for item in corr_cols:
    print(item[0][-4:], 'correlation :', returns_2021_final_df[item[0]].corr(returns_2021_final_df[item[1]]))
# Out:
# 2017 correlation : 0.09910243148275975
# 2018 correlation : 0.18085827153844813
# 2019 correlation : -0.10890844492736551
# 2020 correlation : -0.0367168880505617
# 2021 correlation : 0.06962525217835737

# %% [markdown]
# ## Standard deviation (proxy for volatility) by year

# %%
#calculate standard deviation for each stock from 2019-2021
cols_to_keep = [e for e in full_df.columns.tolist() if 'Close' in e]
std_2019_2021 = full_df[cols_to_keep].std()
std_2019_2021.index = [e.replace('_Close', '') for e in std_2019_2021.index.tolist()]
std_2019_2021
# Out:
# AAPL     31.792638
# MSFT     43.329275
# V        22.477855
# NVDA    159.435383
# MA       45.632682
#            ...
# TMUS     21.622826
# TTWO     32.224883
# TWTR     11.347538
# VIAC     14.329665
# VZ        2.101910
# Length: 94, dtype: float64

# %%
#utilize previously calculated standard deviations of stock prices 2019-2021 to make a new column with standard deviations of prices
std_2019_2021_df = std_2019_2021.to_frame().reset_index()
std_2019_2021_df.columns = ['index', 'standard_deviation']

# %%
returns_2021_final_df = returns_2021_final_df.merge(std_2019_2021_df, left_on='Ticker', right_on='index')
returns_2021_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 57  GOOGL                  22.3  Communication Services            4.0
# 58   NFLX                  17.4  Communication Services            2.0
# 59   NWSA                  13.4  Communication Services            0.0
# 60   TTWO                  17.3  Communication Services            3.0
# 61   VIAC                  16.1  Communication Services            1.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021 index_x  \
# 0             4.0            4.0            3.0            3.0    AAPL
# 1             6.0            6.0            6.0            6.0    MSFT
# 2             4.0            4.0            4.0            4.0       V
# 3             6.0            6.0            6.0            6.0    NVDA
# 4             3.0            4.0            4.0            4.0      MA
# ..            ...            ...            ...            ...     ...
# 57            4.0            5.0            5.0            3.0   GOOGL
# 58            2.0            1.0            1.0            2.0    NFLX
# 59            0.0            0.0            0.0            0.0    NWSA
# 60            3.0            3.0            3.0            3.0    TTWO
# 61            1.0            1.0            2.0            3.0    VIAC
#
#     2019-2021 Returns  ... index_y  2019 Returns index_x  2020 Returns  \
# 0            3.383485  ...    AAPL      1.859486    AAPL      1.767138
# 1            2.517405  ...    MSFT      1.559533    MSFT      1.384759
# 2            1.756320  ...       V      1.413632       V      1.144464
# 3            4.485905  ...    NVDA      1.727353    NVDA      2.176650
# 4            2.085222  ...      MA      1.573680      MA      1.176505
# ..                ...  ...     ...           ...     ...           ...
# 57           2.236735  ...   GOOGL      1.269949   GOOGL      1.280533
# 58           1.892401  ...    NFLX      1.208884    NFLX      1.639520
# 59           2.297629  ...    NWSA      1.241440    NWSA      1.244460
# 60           1.676570  ...    TTWO      1.177098    TTWO      1.702081
# 61           0.907359  ...    VIAC      0.919185    VIAC      0.885246
#
#    index_y  2021 Returns index_x  standard_deviation_x index_y  \
# 0     AAPL      1.032223    AAPL             31.792638    AAPL
# 1     MSFT      1.169369    MSFT             43.329275    MSFT
# 2        V      1.072052       V             22.477855       V
# 3     NVDA      1.164964    NVDA            159.435383    NVDA
# 4       MA      1.125637      MA             45.632682      MA
# ..     ...           ...     ...                   ...     ...
# 57   GOOGL      1.366664   GOOGL            311.163710   GOOGL
# 58    NFLX      0.968749    NFLX             88.789331    NFLX
# 59    NWSA      1.441079    NWSA              4.123139    NWSA
# 60    TTWO      0.863909    TTWO             32.224883    TTWO
# 61    VIAC      1.131967    VIAC             14.329665    VIAC
#
#     standard_deviation_y
# 0              31.792638
# 1              43.329275
# 2              22.477855
# 3             159.435383
# 4              45.632682
# ..                   ...
# 57            311.163710
# 58             88.789331
# 59              4.123139
# 60             32.224883
# 61             14.329665
#
# [62 rows x 24 columns]

# %%
#find correlation of current Sustainalytics score and 2021 price std. dev.
returns_2021_final_df['Sustainalytics Score'].corr(returns_2021_final_df['standard_deviation_x'])
# Out:
# 0.19157730668856768

# %%
returns_2021_final_df = returns_2021_final_df[[e for e in returns_2021_final_df.columns.tolist() if 'index' not in e]]

# %%
returns_2021_final_df = returns_2021_final_df.iloc[:,:-1]
returns_2021_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 57  GOOGL                  22.3  Communication Services            4.0
# 58   NFLX                  17.4  Communication Services            2.0
# 59   NWSA                  13.4  Communication Services            0.0
# 60   TTWO                  17.3  Communication Services            3.0
# 61   VIAC                  16.1  Communication Services            1.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021  \
# ..                ...           ...           ...           ...           ...
# 57           2.236735      1.303697      0.973677      1.269949      1.280533
# 58           1.892401      1.505687      1.331178      1.208884      1.639520
# 59           2.297629      1.386655      0.690810      1.241440      1.244460
# 60           1.676570      2.230394      0.911942      1.177098      1.702081
# 61           0.907359      0.916291      0.738888      0.919185      0.885246
#
#     2021 Returns  2019-2021 standard deviation
# 0       1.032223                     31.792638
# 1       1.169369                     43.329275
# 2       1.072052                     22.477855
# 3       1.164964                    159.435383
# 4       1.125637                     45.632682
# ..           ...                           ...
# 57      1.366664                    311.163710
# 58      0.968749                     88.789331
# 59      1.441079                      4.123139
# 60      0.863909                     32.224883
# 61      1.131967                     14.329665
#
# [62 rows x 15 columns]

# %%
# find yearly std. dev.
std_2019_2021 = full_df[cols_to_keep].std()
std_2019_2021.index = [e.replace('_Close', '') for e in std_2019_2021.index.tolist()]
std_2019_2021

# %%
#create a for loop to make a new column for each year of standard deviations
yearly_dfs = [full_2017_df, full_2018_df, full_2019_df, full_2020_df, full_2021_df]
names = ['2017', '2018', '2019', '2020', '2021']
for i, df in enumerate(yearly_dfs):
    cols_to_keep = [e for e in df.columns.tolist() if 'Close' in e]
    std = df[cols_to_keep].std()
    std.index = [e.replace('_Close', '') for e in std.index.tolist()]
    std_df = std.to_frame().reset_index()
    std_df.columns = ['index', names[i] + ' standard deviation']
    returns_2021_final_df = returns_2021_final_df.merge(std_df, left_on='Ticker', right_on='index').drop(['index'], axis=1)

# %%
returns_2021_final_df
# Out:
#    Ticker  Sustainalytics Score                  Sector  MSCI ESG 2017  \
# 0    AAPL                  16.9                    Tech            4.0
# 1    MSFT                  14.6                    Tech            6.0
# 2       V                  17.4                    Tech            4.0
# 3    NVDA                  13.3                    Tech            5.0
# 4      MA                  16.3                    Tech            3.0
# ..    ...                   ...                     ...            ...
# 57  GOOGL                  22.3  Communication Services            4.0
# 58   NFLX                  17.4  Communication Services            2.0
# 59   NWSA                  13.4  Communication Services            0.0
# 60   TTWO                  17.3  Communication Services            3.0
# 61   VIAC                  16.1  Communication Services            1.0
#
#     MSCI ESG 2018  MSCI ESG 2019  MSCI ESG 2020  MSCI ESG 2021  \
# 0             4.0            4.0            3.0            3.0
# 1             6.0            6.0            6.0            6.0
# 2             4.0            4.0            4.0            4.0
# 3             6.0            6.0            6.0            6.0
# 4             3.0            4.0            4.0            4.0
# ..            ...            ...            ...            ...
# 57            4.0            5.0            5.0            3.0
# 58            2.0            1.0            1.0            2.0
# 59            0.0            0.0            0.0            0.0
# 60            3.0            3.0            3.0            3.0
# 61            1.0            1.0            2.0            3.0
#
#     2019-2021 Returns  2017 Returns  2018 Returns  2019 Returns  2020 Returns  \
# 0            3.383485      1.456995      0.915709      1.859486      1.767138
# 1            2.517405      1.366890      1.181734      1.559533      1.384759
# 2            1.756320      1.434214      1.152214      1.413632      1.144464
# 3            4.485905      1.896873      0.669676      1.727353      2.176650
# 4            2.085222      1.436189      1.241854      1.573680      1.176505
# ..                ...           ...           ...           ...           ...
# 57           2.236735      1.303697      0.973677      1.269949      1.280533
# 58           1.892401      1.505687      1.331178      1.208884      1.639520
# 59           2.297629      1.386655      0.690810      1.241440      1.244460
# 60           1.676570      2.230394      0.911942      1.177098      1.702081
# 61           0.907359      0.916291      0.738888      0.919185      0.885246
#
#     2021 Returns  2019-2021 standard deviation  2017 standard deviation  \
# 0       1.032223                     31.792638                 3.655298
# 1       1.169369                     43.329275                 7.001347
# 2       1.072052                     22.477855                 9.626278
# 3       1.164964                    159.435383                38.053559
# 4       1.125637                     45.632682                15.337771
# ..           ...                           ...                      ...
# 57      1.366664                    311.163710                75.367334
# 58      0.968749                     88.789331                21.295641
# 59      1.441079                      4.123139                 1.162943
# 60      0.863909                     32.224883                21.449996
# 61      1.131967                     14.329665                 3.875042
#
#     2018 standard deviation  2019 standard deviation  2020 standard deviation  \
# 0                  5.148465                 8.634745                21.809814
# 1                  7.917807                14.900505                22.995562
# 2                  9.423177                15.227699                15.482331
# 3                 36.499997                24.987922               117.296009
# 4                 16.526604                28.133559                31.671451
# ..                      ...                      ...                      ...
# 57                69.590390                79.791406               175.163230
# 58                48.919174                34.489629                65.612631
# 59                 1.618153                 0.767588                 2.645019
# 60                10.890203                13.324211                25.295006
# 61                 3.434847                 5.051648                 7.459167
#
#     2021 standard deviation
# 0                  6.292745
# 1                 13.227958
# 2                  9.121569
# 3                 40.169207
# 4                 20.883485
# ..                      ...
# 57               168.409098
# 58                22.150523
# 59                 3.146433
# 60                13.498763
# 61                17.849428
#
# [62 rows x 20 columns]

# %%
returns_2021_final_df.to_csv('returns_2021_final_df_2.csv')

# %%
#testing correlation of Sustainalytics ESG score and 2019-2021 returns: no relationship
tech_comms_df_final['Sustainalytics Score'].corr(tech_comms_df_final['return'])
# Out:
# 0.25270164813462265

# %%
#testing correlation of 2021 MSCI ESG score and 2019-2021 returns: no relationship
tech_comms_df_final['MSCI ESG 2021'].corr(tech_comms_df_final['return'])
# Out:
# -0.07756879326467836

# %%
# find annual correlation between MSCI score and standard deviation
corr_cols = [['MSCI ESG 2017', 'MSCI ESG 2018', 'MSCI ESG 2019', 'MSCI ESG 2020', 'MSCI ESG 2021'],
             ['2017 standard deviation', '2018 standard deviation', '2019 standard deviation', '2020 standard deviation', '2021 standard deviation']]
corr_cols = list(zip(*corr_cols))
for item in corr_cols:
    print(item[0][-4:], 'correlation :', returns_2021_final_df[item[0]].corr(returns_2021_final_df[item[1]]))
# Out:
# 2017 correlation : 0.1316958325127827
# 2018 correlation : 0.04042172849732701
# 2019 correlation : 0.056475529651572876
# 2020 correlation : 0.23395523323266273
# 2021 correlation : -0.004111958344359845

# %%
#plot the Sustainalytics ESG score by 2019-2021 returns, no relationship
tech_comms_df_final.plot.scatter(x = 'Sustainalytics Score', y = 'return')
# Out:
# <AxesSubplot:xlabel='Sustainalytics Score', ylabel='return'>

# %%
#plot 2021 MSCI ESG and return - no relationship
tech_comms_df_final.plot.scatter(x = 'MSCI ESG 2021', y = 'return')
# Out:
# <AxesSubplot:xlabel='MSCI ESG 2021', ylabel='return'>
